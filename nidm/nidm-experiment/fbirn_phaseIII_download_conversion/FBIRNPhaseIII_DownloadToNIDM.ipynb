# %%
import os
import rdflib as rdf
#import csv for reading csv files
import csv
#import for reading XLS data dictionary file
import pandas as pd
import uuid
from glob import glob
import tarfile
import dicom as dcm
import re

# %%
g = rdf.Graph()

# %%
nidash = rdf.Namespace("http://nidm.nidash.org#")
prov = rdf.Namespace("http://www.w3.org/ns/prov#")
ncit = rdf.Namespace("http://ncitt.ncit.nih.gov/")
fbirn = rdf.Namespace("http://www.birncommunity.org/collaborators/function-birn/")
xsd = rdf.Namespace("http://www.w3.org/2001/XMLSchema#")
rdfs = rdf.Namespace("http://www.w3.org/2000/01/rdf-schema#")
foaf = rdf.Namespace("http://xmlns.com/foaf/0.1/")
vc = rdf.Namespace("http://www.w3.org/2006/vcard/ns#")
dicom = rdf.Namespace("http://neurolex.org/wiki/Category:DICOM_term/")
dct = rdf.Namespace("http://purl.org/dc/terms/")
dctypes = rdf.Namespace("http://purl.org/dc/dcmitype/")
dcat = rdf.Namespace("http://www.w3.org/ns/dcat#")
nfo = rdf.Namespace("http://www.semanticdesktop.org/ontologies/2007/03/22/nfo#")
list(g.namespaces())
# Out:
# [('xml', rdflib.term.URIRef(u'http://www.w3.org/XML/1998/namespace')),
#  ('rdf', rdflib.term.URIRef(u'http://www.w3.org/1999/02/22-rdf-syntax-ns#')),
#  ('xsd', rdflib.term.URIRef(u'http://www.w3.org/2001/XMLSchema#')),
#  ('rdfs', rdflib.term.URIRef(u'http://www.w3.org/2000/01/rdf-schema#'))]

# %%
g.bind('nidash', nidash)
g.bind('prov', prov)
g.bind('ncit', ncit)
g.bind('fbirn', fbirn)
g.bind('xsd',xsd)
g.bind('rdfs',rdfs)
g.bind('foaf',foaf)
g.bind('vc',vc)
g.bind('dicom',dicom)
g.bind('dct',dct)
g.bind('dctypes', dctypes)
g.bind('dcat', dcat)
g.bind('nfo',nfo)
list(g.namespaces())
# Out:
# [('xml', rdflib.term.URIRef(u'http://www.w3.org/XML/1998/namespace')),
#  ('fbirn',
#   rdflib.term.URIRef(u'http://www.birncommunity.org/collaborators/function-birn/')),
#  ('vc', rdflib.term.URIRef(u'http://www.w3.org/2006/vcard/ns#')),
#  ('ncit', rdflib.term.URIRef(u'http://ncitt.ncit.nih.gov/')),
#  ('rdfs', rdflib.term.URIRef(u'http://www.w3.org/2000/01/rdf-schema#')),
#  ('nfo',
#   rdflib.term.URIRef(u'http://www.semanticdesktop.org/ontologies/2007/03/22/nfo#')),
#  ('prov', rdflib.term.URIRef(u'http://www.w3.org/ns/prov#')),
#  ('nidash', rdflib.term.URIRef(u'http://nidm.nidash.org#')),
#  ('dctypes', rdflib.term.URIRef(u'http://purl.org/dc/dcmitype/')),
#  ('rdf', rdflib.term.URIRef(u'http://www.w3.org/1999/02/22-rdf-syntax-ns#')),
#  ('foaf', rdflib.term.URIRef(u'http://xmlns.com/foaf/0.1/')),
#  ('xsd', rdflib.term.URIRef(u'http://www.w3.org/2001/XMLSchema#')),
#  ('dicom',
#   rdflib.term.URIRef(u'http://neurolex.org/wiki/Category:DICOM_term/')),
#  ('dcat', rdflib.term.URIRef(u'http://www.w3.org/ns/dcat#')),
#  ('dct', rdflib.term.URIRef(u'http://purl.org/dc/terms/'))]

# %% [markdown]
# #Functions for AssessmentOM

# %%
def nidm_add_elements(g,line,assessment_name, variable_name_id, question_id, type_id):
    #Create new node for each element with metadata consistent with NIDM-Experiment assessment acquistion
    g.add((nidash[line[variable_name_id]], rdf.RDF.type, nidash["DataElement"]))
    g.add((nidash[line[variable_name_id]], rdf.RDF.type, rdf.RDF.Property))
    g.add((nidash[line[variable_name_id]], rdf.RDF.type, rdf.RDF.Property))
    g.add((nidash[line[variable_name_id]], prov["label"], rdf.Literal(line[variable_name_id])))
    if (type_id in line.keys()):
        g.add((nidash[line[variable_name_id]], nidash["DataType"], rdf.Literal(line[type_id])))
    if (question_id in line.keys()):
        g.add((nidash[line[variable_name_id]], nidash["Question"], rdf.Literal(line[question_id])))
    if ('SCORESEQ' in line.keys()):
        g.add((nidash[line[variable_name_id]], nidash["Sequence"], rdf.Literal(line["SCORESEQ"])))   
    #make association with assessment
    g.add((nidash[assessment_name],prov["hadMember"], nidash[line[variable_name_id]]))
def nidm_create_assessment(g, assessment_name):
    g.add((nidash[assessment_name], rdf.RDF.type, nidash["DataStructure"]))
    g.add((nidash[assessment_name],prov["label"],rdf.Literal(assessment_name)))
def nidm_add_codedproperty(g,line,valueset_id, codedvalue_id, score_code_id, score_label_id):
    codedvalue_uri = safe_uri(codedvalue_id)
    g.add((nidash[codedvalue_uri], rdf.RDF.type, nidash["CodedProperty"]))
    g.add((nidash[codedvalue_uri], rdf.RDF.type, rdf.RDF.Property))
    g.add((nidash[codedvalue_uri],nidash["code"], rdf.Literal(line[score_code_id])))
    g.add((nidash[codedvalue_uri], prov["label"], rdf.Literal(line[score_label_id])))
    g.add((nidash[valueset_id], prov["hadMember"], nidash[codedvalue_uri]))
def safe_uri(string):
    return string.strip().replace(" ","_").replace("-", "_").replace(",", "_").replace("(", "_").replace(")","_").replace("'","_").replace("/", "_")
def nidm_create_assessment_acquisition_object(g, object_id, assessment_type):
    g.add((nidash[object_id], rdf.RDF.type, nidash["AssessmentAcquisitionObject"]))
    g.add((nidash[object_id], rdf.RDF.type, nidash[assessment_type]))
    g.add((nidash[object_id], rdf.RDF.type, prov["Entity"]))
def nidm_add_elements_assessment_acquisition_object(g, object_id, element, value):
    g.add((nidash[object_id], nidash[element], rdf.Literal(value)))

# %% [markdown]
# #Functions for ExperimentOM - Investigation Level

# %%
def nidm_create_investigation(g, uid, expid):
    g.add((nidash[uid], rdf.RDF.type, dctypes["Dataset"]))
    g.add((nidash[uid], rdf.RDF.type, nidash["Investigation"]))
    g.add((nidash[uid], rdf.RDF.type, prov["Entity"]))
    g.add((nidash[uid], fbirn["ExperimentID"], rdf.Literal(expid, lang='en')))
def nidm_add_investigation_metadata(g, uid, name, description, baseuri, storagetype):
    g.add((nidash[uid], dct["title"], rdf.Literal(name, lang='en')))
    g.add((nidash[uid], dct["description"], rdf.Literal(description, lang='en')))
    g.add((nidash[uid], dct["publisher"], rdf.URIRef(baseuri)))
    g.add((nidash[uid], dcat["accessURL"], rdf.URIRef(baseuri)))
    g.add((nidash[uid], fbirn["StorageType"], rdf.Literal(storagetype, lang='en')))
def nidm_add_role(g, uid, role):
    g.add((uid, rdf.RDF.type, prov["Role"]))
    g.add((uid, prov["label"], rdf.Literal(role)))
def nidm_add_investigation_PI(g, uid, expid, first, last, email):
    g.add((nidash[uid], rdf.RDF.type, prov["Person"]))
    g.add((nidash[uid], foaf["givenName"], rdf.Literal(first)))
    g.add((nidash[uid], foaf["familyName"], rdf.Literal(last)))
    g.add((nidash[uid], vc["email"], rdf.Literal(email)))
    #connect Person to Experiment and add Role
    nidm_add_role(g, nidash["PI"], "Principle Investigator")
    g.add((nidash[uid], prov["hadRole"], nidash["PI"]))
    g.add((nidash[uid], prov["wasAssociatedWith"], nidash[expid]))

# %%
#experiment and person dictionaries for lookup
exp_dict = {}
exp_collection_dict = {}
person_dict = {}
#Create investigation, parse metadata
variables = pd.read_csv("./HID_Download/phaseIII_experiment_info.csv")
#iterate over the variables in the experiment info export
for index, row in variables.iterrows():
    #create UUID
    expid = "Investigation_" + str(uuid.uuid1())
    #keep UUID -> uniqueid mappings for experiments in dictionary in case there are multiple experiments
    exp_dict[expid] = row["uniqueid"]
    #add investigation using HID experiment ID
    nidm_create_investigation(g, expid,exp_dict[expid])
    #add other metadata from file
    nidm_add_investigation_metadata(g, expid, row["name"], row["description"],row["baseuri"],row["storagetype"])

    #create an investigation collection / investigation activity
    collectid = "InvestigationCollection_" + str(uuid.uuid1())
    #store URL for later use
    exp_collection_dict[str(row["uniqueid"])] = collectid
    
    activityid = "InvestigationActivity_"+str(uuid.uuid1())
    g.add((nidash[collectid], rdf.RDF.type, prov["Collection"]))
    g.add((nidash[activityid], rdf.RDF.type, prov["Activity"]))
    #add label for debugging/model evaluation
    g.add((nidash[collectid],prov["label"], rdf.Literal("Investigation Collection")))
    g.add((nidash[activityid],prov["label"], rdf.Literal("Investigation Process Activity")))
    #associate investigation entity with collection
    g.add((nidash[collectid], prov["hadMember"], nidash[expid]))
    g.add((nidash[collectid],prov["wasGeneratedBy"], nidash[activityid]))
    
    #Create PI person, parse metadata
    person_variables = pd.read_csv("./HID_Download/phaseIII_PI_info.csv")
    for person_index, person_row in person_variables.iterrows():
        #create UUID
        PIid = "Person_" + str(uuid.uuid1())
        #keep UUID -> uniqueid mappings for persons in dictionary in case there are multiple person
        person_dict[PIid] = person_row["uniqueid"]
        #add PI 
        nidm_add_investigation_PI(g, PIid, expid, person_row["first_name"], person_row["last_name"], person_row["email"])
        #associate person with investigation activity
        g.add((nidash[activityid],prov["wasAssociatedWith"], nidash[PIid]))
        #associate investigation activity with person
        g.add((nidash[collectid],prov["wasAttributedTo"], nidash[PIid]))

# %% [markdown]
# #Image series (DICOM) download parsing/conversion to NIDM

# %%
#Image series functions
def nidm_add_session_person(g, uid, subjid):
    g.add((nidash[uid], rdf.RDF.type, prov["Person"]))
    g.add((nidash[uid], ncit["subjectID"], rdf.Literal(subjid)))
    nidm_add_role(g, nidash["Participant"], "Participant")
    g.add((nidash[uid], prov["hadRole"], nidash["Participant"]))
def nidm_add_scanner(g, uid, dicom_hdr):
    g.add((nidash[scanner_id], rdf.RDF.type, prov["Agent"]))
    g.add((nidash[scanner_id], dicom["Manufacturer"], rdf.Literal(ds[0x0008, 0x0070].value)))
    g.add((nidash[scanner_id], dicom["ManufacturerModelName"], rdf.Literal(ds[0x0008,0x1090].value)))
    g.add((nidash[scanner_id], dicom["MagneticFieldStrength"], rdf.Literal(ds[0x0018,0x0087].value)))
    g.add((nidash[scanner_id], dicom["DeviceSerialNumber"], rdf.Literal(ds[0x0018,0x1000].value)))
    g.add((nidash[scanner_id], dicom["SoftwareVersion"], rdf.Literal(ds[0x0018,0x1020].value)))
def nidm_add_dicom_metadata(g, uid, dicom_hdr):
    g.add((nidash[uid], dicom["ScanningSequence"], rdf.Literal(ds[0x0018,0x0020].value)))
    g.add((nidash[uid], dicom["SequenceVariant"], rdf.Literal(ds[0x0018,0x0021].value)))
    g.add((nidash[uid], dicom["ScanOptions"], rdf.Literal(ds[0x0018,0x0022].value)))
    g.add((nidash[uid], dicom["MRAcquisitionType"], rdf.Literal(ds[0x0018,0x0023].value)))
    g.add((nidash[uid], dicom["SequenceName"], rdf.Literal(ds[0x0018,0x0024].value)))
    g.add((nidash[uid], dicom["AngioFlag"], rdf.Literal(ds[0x0018,0x0025].value)))
    g.add((nidash[uid], dicom["SliceThickness"], rdf.Literal(ds[0x0018,0x0050].value)))
    g.add((nidash[uid], dicom["RepetitionTime"], rdf.Literal(ds[0x0018,0x0080].value)))
    g.add((nidash[uid], dicom["EchoTime"], rdf.Literal(ds[0x0018,0x0081].value)))
    g.add((nidash[uid], dicom["NumberofAverages"], rdf.Literal(ds[0x0018,0x0083].value)))
    g.add((nidash[uid], dicom["ImagingFrequency"], rdf.Literal(ds[0x0018,0x0084].value)))
    g.add((nidash[uid], dicom["ImagedNucleus"], rdf.Literal(ds[0x0018,0x0085].value)))
    g.add((nidash[uid], dicom["EchoNumber"], rdf.Literal(ds[0x0018,0x0086].value)))
    g.add((nidash[uid], dicom["MagneticFieldStrength"], rdf.Literal(ds[0x0018,0x0087].value)))
    g.add((nidash[uid], dicom["SpacingBetweenSlices"], rdf.Literal(ds[0x0018,0x0088].value)))
    g.add((nidash[uid], dicom["NumberofPhaseEncodingSteps"], rdf.Literal(ds[0x0018,0x0089].value)))
    g.add((nidash[uid], dicom["EchoTrainLength"], rdf.Literal(ds[0x0018,0x0091].value)))
    g.add((nidash[uid], dicom["PercentSampling"], rdf.Literal(ds[0x0018,0x0093].value)))
    g.add((nidash[uid], dicom["PercentPhaseFieldofView"],rdf.Literal(ds[0x0018,0x0094].value)))
    g.add((nidash[uid], dicom["PixelBandwidth"],rdf.Literal(ds[0x0018,0x0095].value)))
    g.add((nidash[uid], dicom["ProtocolName"],rdf.Literal(ds[0x0018,0x1030].value)))
    g.add((nidash[uid], dicom["TransmitCoilName"],rdf.Literal(ds[0x0018,0x1251].value)))
    g.add((nidash[uid], dicom["AcquisitionMatrix"],rdf.Literal(ds[0x0018,0x1310].value)))
    g.add((nidash[uid], dicom["InplanePhaseEncodingDirection"],rdf.Literal(ds[0x0018,0x1312].value)))
    g.add((nidash[uid], dicom["FlipAngle"], rdf.Literal(ds[0x0018,0x1314].value)))
    g.add((nidash[uid], dicom["VariableFlipAngleFlag"], rdf.Literal(ds[0x0018,0x1315].value)))
    g.add((nidash[uid], dicom["SAR"], rdf.Literal(ds[0x0018,0x1316].value)))
    g.add((nidash[uid], dicom["dB_dt"], rdf.Literal(ds[0x0018,0x1318].value)))
    g.add((nidash[uid], dicom["PatientPosition"], rdf.Literal(ds[0x0018,0x5100].value)))

# %%
#traverse directory structure, store visit/study metadata parsed from directory names per
#FBIRN hierarchy, parse DICOM metadata at lowest level and format according to NIDM
root_dir = "./HID_Download/"
subj_dict={}
#session_dict={}

#create visit dictionary
visit_dict = {}  
for dname in os.listdir(root_dir):
    if ((os.path.isdir(os.path.join(root_dir,dname))) and (not dname.startswith('.'))):
        #highest level directory contains subj-dirs with subjectID
        #grab subjectID and store in NIDM-Experiment graph
        #subject ID should be unique so can drop the UUID...and then we don't need a dictionary
        #subj_uid = dname + "_" + str(uuid.uuid1())
        subj_uid = str(dname)
        subj_dict[dname] = subj_uid
        nidm_add_session_person(g,subj_uid, dname)
    
        ###VISIT COLLECTION TAKES PLACE OF THIS CODE....####
        #create session activity and collection
        #create an investigation collection / investigation activity
        #collectid = "SessionCollection_" + str(uuid.uuid1())
        
        #key session collection by subjectID+visit_number
        #session_dict[dname + "_" + tokens[2]] = collectid
        #activityid = "SessionActivity_"+str(uuid.uuid1())
        #g.add((nidash[collectid], rdf.RDF.type, prov["Collection"]))
        #g.add((nidash[activityid], rdf.RDF.type, prov["Activity"]))
        
        #associate person with these session collections/activities
        #g.add((nidash[collectid], prov["wasAttributedTo"], nidash[subj_uid]))
        #g.add((nidash[activityid], prov["wasAssociatedWith"], nidash[subj_uid]))

        #now start traversing, next level is visit level
      
        for visitname in os.listdir(os.path.join(root_dir,dname)):
            if ((os.path.isdir(os.path.join(root_dir,dname,visitname))) and (not visitname.startswith('.'))):
                #next sub dirs are visits
                #parse visit info from directory name
                tokens=visitname.split("__")
                #token[0] = visitname, token[1] = siteid, token[2] = visit number
                #add visit entity and associate wtih session collection
                #visit unique id is "Visit_"+visit number+visit name + subjectID
                visitid = "Visit_" + str(tokens[2]) + "_" + str(tokens[0]) + "_" + dname
                visit_dict[dname + "_" + tokens[2]] = visitid
                g.add((nidash[visitid], rdf.RDF.type, prov["Entity"]))
                g.add((nidash[visitid], rdf.RDF.type, nidash["Session"]))
                g.add((nidash[visitid], ncit["VisitNum"], rdf.Literal(tokens[2])))
                g.add((nidash[visitid], ncit["StudySiteNumber"], rdf.Literal(tokens[1])))
                g.add((nidash[visitid], prov["label"], rdf.Literal(tokens[0])))
                #g.add((nidash[collectid], prov["hadMember"], nidash[visitid]))
                #visit collection is the "session" collection, attribute to subject
                g.add((nidash[visitid], prov["wasAttributedTo"], nidash[subj_dict[dname]]))
                
                #create scanner dictionary for use in scanners associated with series acquisitions
                scanner_dict={}
                
                #Study Level
                for studyname in os.listdir(os.path.join(root_dir,dname, visitname)):
                    #Skip Levels until Series Level...where do we put multiple studies in model?
                    if ((os.path.isdir(os.path.join(root_dir,dname,visitname,studyname))) and (not studyname.startswith('.'))):
                        for seriesname in os.listdir(os.path.join(root_dir,dname, visitname,studyname)):
                            if ((os.path.isdir(os.path.join(root_dir,dname,visitname,studyname,seriesname))) and (not seriesname.startswith('.'))):
                                #traverse series level directories to get DICOM data
                                #here we need to separate out structural from functional series. 
                                #for FBIRN the directory names will tell us but for other data sets
                                #we should match the DICOM tags to a classification scheme
                                if ((seriesname.lower().find("t1") ) or (seriesname.lower().find("t2"))):
                                    #we have an anatomical scan so create an anatomical image acquisition activity 
                                    #create an anatomical scan entity and populate
                                    session_act_id = "AnatomicalAcquisition_" + str(uuid.uuid1()) 
                                else:
                                    session_act_id = "FunctionalAcquisition_" + str(uuid.uuid1())
                                    
                                g.add((nidash[session_act_id], rdf.RDF.type, prov["Activity"]))
                                #get some metadata about the activity by parsing the DICOM tags
                                fname = os.path.join(root_dir,dname,visitname,studyname,seriesname,"Native","Original__0001","DICOM.tar.gz")
                                tar = tarfile.open(fname, "r:gz")
                                try:
                                    tar_contents = tar.getmembers()
                                    for files in tar_contents:
                                        if ".dcm" in files.name:
                                            dcmfilename = files.name
                                            #print dcmfilename + "found!"
                                            break
                                     
                                    dcmfile = tar.extractfile(dcmfilename)
                                        
                                    #for member in tar.getmembers():
                                    #    print member
                                    #now get DICOM header tags
                                    ds = dcm.read_file(dcmfile)
                                    #add acquisition time to activity object
                                    g.add((nidash[session_act_id], prov["startedAtTime"], rdf.Literal(ds[0x0008,0x0031].value)))
                                    #create scanner unless it already exists then just associate with acquisition object
                                    scanner_key = str(ds[0x0008, 0x0070].value)+ "_"+str(ds[0x0008,0x1090].value)+"_"+str(ds[0x0018,0x0087].value)
                                    if scanner_dict.has_key(scanner_key):
                                        #associate with acquisition activity and scan entity
                                        g.add((nidash[session_act_id], prov["wasGeneratedBy"],nidash[scanner_dict[scanner_key]] ))
                                        
                                    else:
                                        #create scanner agent
                                        #key is manufacturer+model+field_strength
                                        scanner_id = scanner_key + str(uuid.uuid1())
                                        scanner_dict[scanner_key] = scanner_id
                                        nidm_add_scanner(g, scanner_id, ds)
                                        #associate scanner agent with acquisition activity
                                        g.add((nidash[session_act_id], prov["Used"], nidash[scanner_id]))
                                        #create scan entity
                                        session_id = "Scan_" + str(uuid.uuid1())
                                        g.add((nidash[session_id], rdf.RDF.type, prov["Entity"]))
                                        #add some metadata....what metadata do we add?
                                        nidm_add_dicom_metadata(g, session_id, ds)
                                        #add filename/location to entity
                                        g.add((nidash[session_id], nfo["filename"], rdf.Literal("DICOM.tar.gz")))
                                        g.add((nidash[session_id], prov["atLocation"], rdf.Literal(os.path.join(dname,visitname,studyname,seriesname,"Native","Original__0001"))))
                                        
                                        #create association with anatomical activity
                                        g.add((nidash[session_id], prov["wasGeneratedBy"], nidash[session_act_id]))
                                except (tarfile.TarError,tarfile.ReadError,tarfile.CompressionError,tarfile.StreamError,tarfile.ExtractError,tarfile.HeaderError):
                                    print "Error opening DICOM file"+dcmfile

# %% [markdown]
# #Assessment modeling

# %%
#HID assessments are downloaded with filenames "data_download_[AssessmentName].csv" where [AssessmentName] matches the 
#name of the assessment in the data dictionary files.
#For FBIRN phase III there are CMINDS assessments along with HID/tablet clinical assessments.  For the CMINDS assessments
#each assessment has a separate XLS file with the data dictionary.  For the HID/tablet clinical assessments, all
#assessments are in the same data dictionary XLS file...so there will be some complexity in modeling these...


#Since we are going to store the data dictionaries in a separate TTL file, create a new graph
dd_graph = rdf.Graph()
#bind namespaces
dd_graph.bind('nidash', nidash)
dd_graph.bind('prov', prov)
dd_graph.bind('ncit', ncit)
dd_graph.bind('nidash', nidash)
dd_graph.bind('fbirn', fbirn)

#Find data_download_[*].csv and loop through them
data_dictionary_dir = "./HID_DataDictionary"
#Added acquired assessment directory for code clarity
assessment_dir = root_dir

#create dictionary of assessment UIDs
assessment_dict = {}
acquired_assessment_dict = {}


#for dd_file in os.listdir(os.path.join(root_dir, "data_download*")):
for dd_file in glob(os.path.join(root_dir, "data_download*")):
    datadic_file = ""
    assessment_name = ""

    #do data dictionary modeling first so parse assessment name from dd_file and see if it's one of the CMINDS tests
    tokens=dd_file.split("_")
    #tokens[1]==data, tokens[2]==download, tokens[3]==assessment_name.csv
    #strip off .csv
    tokens[3] = re.sub('\.csv$','', tokens[3])

    #look for matching file in data_dictionary_dir
    for datadic in glob(os.path.join(data_dictionary_dir,"*")):
        #note, CMINDS assessment data dictionaries are stored in separate files named by the assessment vs. FBIRN clinical
        #data collected on the tablet are all stored in the same data dictionary file....so if we can't find a filename
        #matching tokens[3] then it's not a CMINDS assessment
        if (datadic.find(tokens[3])!= -1):
            
            #check if assessment name has already been encountered, if so use existing ID
            #if assessment_dict.has_key("CMINDS_"+ tokens[3]):
            #    assessment_id = assessment_dict["CMINDS_"+ tokens[3]]
            
            #Removed "CMINDS" string from these assessment keys (see previous 2 lines)...decided not to differentiate
            #CMINDS assessments from tablet-based clinical assessments.  We could do this using an agent which is
            #probably the sematically correct way since they were collected using different devices.
            if assessment_dict.has_key(tokens[3]):
                assessment_id = assessment_dict[tokens[3]]
            
            else:
                #print "found matching data dictionary: " + datadic
                #assessment_id = "CMINDS_"+ tokens[3] + "_" + str(uuid.uuid1())
                #assessment_id = "CMINDS_"+ tokens[3]
                #assessment_dict["CMINDS_"+ tokens[3]] = assessment_id
                
                #this doesn't need to be a dictionary anymore since we ditched the UUIDs.  This dictionary
                #was used to map assessment name -> assessment name + UUID
                assessment_id = tokens[3]+"DataStructure"
                assessment_dict[tokens[3]] = assessment_id
            
               
            #create assessment entity
            nidm_create_assessment(dd_graph, assessment_id)
            
            
            #now open CMINDS data dictionary and start modeling
            #Note, CMINDS data dictionaries are 1 sheet, no value-sets for these
            xls = pd.ExcelFile(datadic)
            #3rd sheet is summary variables
            variables = xls.parse(2)
            #iterate over the variables in the data dictionary
            for index, row in variables.iterrows():
                #add elements to RDF graph for variable definitions
                nidm_add_elements(dd_graph,row,assessment_id, "Variable Name", "Description", "Valid_Values") 
            
                  
        else:
            #assessment not a CMINDS assessment so parse data dictionary stuff from HID PhaseIII data dictionary
            xls = pd.ExcelFile(os.path.join(data_dictionary_dir,"FBIRN_PhaseIII_Assessment_DataDictionary_20110330.xls"))
            variables = xls.parse(0)
            value_sets = xls.parse(1)
            #iterate over the variables in the data dictionary
            for index, row in variables.iterrows():
            
                #check if assessment name has already been encountered, if so use existing ID
                if assessment_dict.has_key(tokens[3]):
                    assessment_id = assessment_dict[tokens[3]]
                else:
                    #print "found matching data dictionary: " + datadic
                    #assessment_id = tokens[3] + "_" + str(uuid.uuid1())
                    
                    #this doesn't need to be a dictionary anymore since we ditched the UUIDs.  This dictionary
                    #was used to map assessment name -> assessment name + UUID
                    assessment_id = tokens[3]+"DataStructure"
                    assessment_dict[tokens[3]] = assessment_id
            
                #create assessment entity
                nidm_create_assessment(dd_graph, assessment_id)
            
                
                #if assessment name in column A matches the assessment name in the data_download_[assessment name].csv
                #filename then we'll start parsing the value set information from the other columns
                if (row['Assessment Name'].find(tokens[3])!=-1):
                    #print "Found match: " + tokens[3] + " in " + row['Assessment Name']
                    #add elements to RDF graph for variable definitions
                    nidm_add_elements(dd_graph,row,assessment_id, "Data ID", "Question Text","") 
                    
                    #look for value sets in data dictionary that match the assessment name+variable name
                    query_sets = value_sets[value_sets["Data ID"].str.contains(row["Data ID"])]
                    #iterate over the value set rows and add to RDF graph
                    for query_index, query_row in query_sets.iterrows():
                        #print query_row['SCORECODE'] + "," + query_row['SCORELABEL'] 
                        #add attribute to coded data element for valueset
                        #valueset_id = assessment_id+"_"+row["Data ID"]+"_ValueSet"
                        valueset_id = row["Data ID"]+"_ValueSet"
                        dd_graph.add((nidash[row["Data ID"]], nidash["ValueSet"], nidash[valueset_id]))
                        #create value set collection
                        dd_graph.add((nidash[valueset_id], rdf.RDF.type, prov["Collection"]))
                        dd_graph.add((nidash[valueset_id], rdf.RDF.type, nidash["ValueSet"]))
                        nidm_add_codedproperty(dd_graph, query_row, valueset_id ,row["Data ID"] + "_" + str(query_row["SCORECODE"]), "SCORECODE","SCORELABEL" )
    
    #parse/model measured assessments
    input_file = csv.DictReader(open(dd_file))
    
    #dictionary keys to skip during assessment data modeling
    nondata_keys = ['SubjectID', 'SiteID', 'ExperimentID', 'VisitID', 'SegmentID']
    
    #figure out which experiment, subj, site, and visit each row corresponds to and model assessment data
    #match with assessment from data dictionary
    if assessment_dict.has_key(tokens[3]):
        assessment_id = assessment_dict[tokens[3]]
    else:
        #if this happens we won't be able to link the assessment data to a data dictionary class
        #so let's just create an ad-hoc assessment in the data dictionary with no items unfortunately.  We could
        #create an empirical data dictionary from the collected assessment data as we did with the SimpleData 
        #example: https://github.com/incf-nidash/nidm/tree/master/nidm/nidm-experiment/simpledata_example_ohbm_hack_2016
        assessment_id = tokens[3]+"DataStructure"+"_"+str(uuid.uuid1())
        nidm_create_assessment(dd_graph, assessment_id)
        print "ERROR: Assessment data found with no matching data dictionary class!!"
        print "Creating assessment object in data dictionary with no elements. Consider creating empirical data dictionary!"

 
    #each row is a subject observation key'd by subjID, siteID, ExperimentID, and VisitID
    for line in input_file:
        #create assessment collection activity for each subject/project/visit/assessment
        activity_uri = "AssessmentCollectionActivity_"+line["SubjectID"]+"_"+str(line["VisitID"]).rjust(4,'0')
        #add activity to graph
        g.add((nidash[activity_uri], rdf.RDF.type, prov["Activity"]))
        #add label for debugging/model evaluation
        g.add((nidash[activity_uri],prov["label"], rdf.Literal(" Assessment Data Collection Activity")))
  
        #match data to correct experiment 
        if exp_collection_dict.has_key(str(line["ExperimentID"])):
            #print "Found Experiment Collection Object"
            #associate acquired assessment with experiment acquisition activity
            g.add((nidash[activity_uri], prov["wasAssociatedWith"], nidash[exp_collection_dict[str(line["ExperimentID"])]]))
        #associate activity with subject agent
        if subj_dict.has_key(str(line["SubjectID"])):
            #associated activity with subject
            g.add((nidash[activity_uri], prov["wasAssociatedWith"], nidash[subj_dict[str(line["SubjectID"])]]))
        else:
            #create subject
            subj_uid = str(line["SubjectID"])
            subj_dict[str(line["SubjectID"])] = subj_uid
            nidm_add_session_person(g,subj_uid, subj_uid)
    
        #associate activity with Visit
        if visit_dict.has_key(str(line["SubjectID"]) + "_" + str(line["VisitID"]).rjust(4,'0')):
            #print "Found Visit Collection Object"
            #associate acitivity with visit
            g.add((nidash[activity_uri], prov["wasAssociatedWith"], nidash[visit_dict[str(line["SubjectID"]) + "_" + str(line["VisitID"]).rjust(4,'0')]]))
        else:
            #if not session_dict.has_key(str(line["SubjectID"]) + "_" + str(line["VisitID"]).rjust(4,'0')):
                #create a session for this visit
            #    collectid = "SessionCollection_" + str(uuid.uuid1())
            #    session_dict[str(line["SubjectID"]) + "_" + str(line["VisitID"]).rjust(4,'0')] = collectid
            
            #add visit to session collection
            #add a visit collection for this visit
            visitid = "Visit_" + str(line["VisitID"]).rjust(4,'0') + "_" + "AssessmentAcquisition" + "_" + str(line["SubjectID"])
            visit_dict[str(line["SubjectID"]) + "_" + str(line["VisitID"]).rjust(4,'0')] = visitid
            g.add((nidash[visitid], rdf.RDF.type, prov["Entity"]))
            g.add((nidash[visitid], rdf.RDF.type, nidash["Session"]))
            g.add((nidash[visitid], ncit["VisitNum"], rdf.Literal(line["VisitID"])))
            g.add((nidash[visitid], ncit["StudySiteNumber"], rdf.Literal(line["SiteID"])))
            g.add((nidash[visitid], prov["label"], rdf.Literal("Assessment Acquisition Visit")))
            #g.add((nidash[session_dict[str(line["SubjectID"]) + "_" + str(line["VisitID"]).rjust(4,'0')]], prov["hadMember"], nidash[visitid]))
            #associate subject with visit collection
            #visit collection is the "session" collection, attribute to subject
            g.add((nidash[visitid], prov["wasAttributedTo"], nidash[subj_dict[str(line["SubjectID"])]]))
                
            #associate assessment acquisition acitivity with visit
            g.add((nidash[activity_uri], prov["wasAssociatedWith"], nidash[visit_dict[str(line["SubjectID"]) + "_" + str(line["VisitID"]).rjust(4,'0')]]))

        #create an entity for the assessment data
        acquired_assessment_id = tokens[3] + "_" + line["SubjectID"] + "_" + str(line["VisitID"]).rjust(4,'0')
        nidm_create_assessment_acquisition_object(g, acquired_assessment_id, assessment_id)
        #add assessment items to entity but need to skip subjID, siteID, experimentID, and visitID columns
        
        for items in input_file.fieldnames:
            #if this key is not one of the non-data columns (see nondata_keys above) then it's data from the 
            #assessment
            if items not in nondata_keys:
                #add the data to our entity
                nidm_add_elements_assessment_acquisition_object(g, acquired_assessment_id, items, line[items])
        
        #add association with activity
        g.add((nidash[acquired_assessment_id], prov["wasGeneratedBy"], nidash[activity_uri]))

# %%
print g.serialize(format='turtle')
# Out:
# @prefix dcat: <http://www.w3.org/ns/dcat#> .
# @prefix dct: <http://purl.org/dc/terms/> .
# @prefix dctypes: <http://purl.org/dc/dcmitype/> .
# @prefix dicom: <http://neurolex.org/wiki/Category:DICOM_term/> .
# @prefix fbirn: <http://www.birncommunity.org/collaborators/function-birn/> .
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix ncit: <http://ncitt.ncit.nih.gov/> .
# @prefix nfo: <http://www.semanticdesktop.org/ontologies/2007/03/22/nfo#> .
# @prefix nidash: <http://nidm.nidash.org#> .
# @prefix prov: <http://www.w3.org/ns/prov#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix vc: <http://www.w3.org/2006/vcard/ns#> .
# @prefix xml: <http://www.w3.org/XML/1998/namespace> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# nidash:AIMS_001312253228_0001 a nidash:AIMSDataStructure,
#         nidash:AssessmentAcquisitionObject,
#         prov:Entity ;
#     nidash:AIMS___Abnormal_Involuntary_Movement_scale_nAIMS_AWARENESS "0" ;
#     nidash:AIMS___Abnormal_Involuntary_Movement_scale_nAIMS_DENTURES "0" ;
#     nidash:AIMS___Abnormal_Involuntary_Movement_scale_nAIMS_FACIAL "0" ;
#     nidash:AIMS___Abnormal_Involuntary_Movement_scale_nAIMS_INCAPACITATION "0" ;
#     nidash:AIMS___Abnormal_Involuntary_Movement_scale_nAIMS_JAW "0" ;
#     nidash:AIMS___Abnormal_Involuntary_Movement_scale_nAIMS_LATERALITY "0" ;
#     nidash:AIMS___Abnormal_Involuntary_Movement_scale_nAIMS_LOWER "0" ;
#     nidash:AIMS___Abnormal_Involuntary_Movement_scale_nAIMS_NECK "0" ;
#     nidash:AIMS___Abnormal_Involuntary_Movement_scale_nAIMS_PERIORAL "0" ;
#     nidash:AIMS___Abnormal_Involuntary_Movement_scale_nAIMS_SEVERITY "0" ;
#     nidash:AIMS___Abnormal_Involuntary_Movement_scale_nAIMS_TEETH "1" ;
#     nidash:AIMS___Abnormal_Involuntary_Movement_scale_nAIMS_TONGUE "0" ;
#     nidash:AIMS___Abnormal_Involuntary_Movement_scale_nAIMS_UPPER "0" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_001312253228_0001 .
#
# nidash:AnatomicalAcquisition_b862fa61-60b2-11e6-9ff3-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "130117.171000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3b862754c-60b2-11e6-bed7-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_b8b7904a-60b2-11e6-a545-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "125920.078000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3b862754c-60b2-11e6-bed7-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_b8bcf663-60b2-11e6-b842-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "140557.125000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3b862754c-60b2-11e6-bed7-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_b95de999-60b2-11e6-8e3e-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "141127.359000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3b862754c-60b2-11e6-bed7-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_b9fa64dc-60b2-11e6-b6bc-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "125857.125000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3b862754c-60b2-11e6-bed7-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_ba08b56e-60b2-11e6-a8bb-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "125857.953000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3b862754c-60b2-11e6-bed7-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_ba107acc-60b2-11e6-99d1-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "141937.187000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3b862754c-60b2-11e6-bed7-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_bb2cb34f-60b2-11e6-a90f-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "130737.125000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3b862754c-60b2-11e6-bed7-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_bc1357b0-60b2-11e6-b694-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "131507.359000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3b862754c-60b2-11e6-bed7-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_bcf1b55c-60b2-11e6-8d7b-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "132217.156000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3b862754c-60b2-11e6-bed7-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_bdd0ad4f-60b2-11e6-98e9-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "133527.359000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3b862754c-60b2-11e6-bed7-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_bea96ad1-60b2-11e6-9f00-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "134237.156000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3b862754c-60b2-11e6-bed7-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_bf821e73-60b2-11e6-acd7-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "135127.359000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3b862754c-60b2-11e6-bed7-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_c05c848f-60b2-11e6-8876-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "135837.156000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3b862754c-60b2-11e6-bed7-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_c133a9f3-60b2-11e6-b73d-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "134957.125000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3b862754c-60b2-11e6-bed7-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_c1517ba6-60b2-11e6-98b2-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "132917.125000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3b862754c-60b2-11e6-bed7-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_c2030a2e-60b2-11e6-a5e9-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "125511.765000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3b862754c-60b2-11e6-bed7-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_c266ad68-60b2-11e6-a798-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "125751.312000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3b862754c-60b2-11e6-bed7-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_c27eb90a-60b2-11e6-b369-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "150149.899000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3c27e4cde-60b2-11e6-87cb-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_c2ddaf14-60b2-11e6-8216-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "145918.518000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3c27e4cde-60b2-11e6-87cb-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_c2e283b8-60b2-11e6-9381-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "161718.901000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3c27e4cde-60b2-11e6-87cb-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_c388acf3-60b2-11e6-8625-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "162305.493000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3c27e4cde-60b2-11e6-87cb-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_c42cf905-60b2-11e6-869e-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "145856.814000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3c27e4cde-60b2-11e6-87cb-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_c43a8791-60b2-11e6-950e-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "145857.080000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3c27e4cde-60b2-11e6-87cb-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_c44356a6-60b2-11e6-8aff-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "163129.871000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3c27e4cde-60b2-11e6-87cb-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_c55934d4-60b2-11e6-a757-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "151138.906000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3c27e4cde-60b2-11e6-87cb-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_c6492aa1-60b2-11e6-83fe-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "152005.488000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3c27e4cde-60b2-11e6-87cb-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_c735b17d-60b2-11e6-a3e5-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "152829.882000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3c27e4cde-60b2-11e6-87cb-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_c829a2e8-60b2-11e6-9e9c-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "154245.493000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3c27e4cde-60b2-11e6-87cb-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_c91a60a1-60b2-11e6-95be-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "155049.871000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3c27e4cde-60b2-11e6-87cb-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_ca0a2523-60b2-11e6-b92a-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "160025.487000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3c27e4cde-60b2-11e6-87cb-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_cafc861e-60b2-11e6-bd6e-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "160829.881000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3c27e4cde-60b2-11e6-87cb-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_cbf2332b-60b2-11e6-aa7b-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "155818.920000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3c27e4cde-60b2-11e6-87cb-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_cc137f0a-60b2-11e6-b57a-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "153558.900000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3c27e4cde-60b2-11e6-87cb-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_ccd1ae11-60b2-11e6-9270-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "145332.350000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3c27e4cde-60b2-11e6-87cb-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_cd2b71b8-60b2-11e6-b73e-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "145749.874000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3c27e4cde-60b2-11e6-87cb-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_cd428359-60b2-11e6-84ed-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "183519.393000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3cd4217a6-60b2-11e6-a83e-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_cd9f6cb0-60b2-11e6-a23b-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "183311.203000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3cd4217a6-60b2-11e6-a83e-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_cda4e911-60b2-11e6-86b9-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "194516.526000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3cd4217a6-60b2-11e6-a83e-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_ce441080-60b2-11e6-9922-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "194958.670000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3cd4217a6-60b2-11e6-a83e-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_cededdb8-60b2-11e6-8eb1-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "183249.516000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3cd4217a6-60b2-11e6-a83e-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_ceec1611-60b2-11e6-87df-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "183249.812000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3cd4217a6-60b2-11e6-a83e-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_cef3c085-60b2-11e6-ad00-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "195839.382000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3cd4217a6-60b2-11e6-a83e-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_cff6e1fd-60b2-11e6-a016-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "184236.527000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3cd4217a6-60b2-11e6-a83e-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_d0df9563-60b2-11e6-bd26-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "184958.676000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3cd4217a6-60b2-11e6-a83e-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_d1ccac11-60b2-11e6-96e1-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "185819.389000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3cd4217a6-60b2-11e6-a83e-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_d2b93e1c-60b2-11e6-a3d1-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "191218.670000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3cd4217a6-60b2-11e6-a83e-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_d3a02d02-60b2-11e6-a42a-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "191939.381000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3cd4217a6-60b2-11e6-a83e-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_d487ef4a-60b2-11e6-b7c2-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "192918.670000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3cd4217a6-60b2-11e6-a83e-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_d570f62b-60b2-11e6-b65e-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "193659.394000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3cd4217a6-60b2-11e6-a83e-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_d65f84cc-60b2-11e6-bce4-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "192716.512000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3cd4217a6-60b2-11e6-a83e-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_d67f8acf-60b2-11e6-bdbb-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "190536.522000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3cd4217a6-60b2-11e6-a83e-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_d7335307-60b2-11e6-b506-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "182828.214000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3cd4217a6-60b2-11e6-a83e-6c4008b8f03e .
#
# nidash:AnatomicalAcquisition_d78d2157-60b2-11e6-a84e-6c4008b8f03e a prov:Activity ;
#     prov:startedAtTime "183142.952000" ;
#     prov:wasGeneratedBy nidash:SIEMENS_TrioTim_3cd4217a6-60b2-11e6-a83e-6c4008b8f03e .
#
# nidash:Barnes_001312253228_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:BarnesDataStructure,
#         prov:Entity ;
#     nidash:Barnes_Scale_nBARS_GLOBAL "0" ;
#     nidash:Barnes_Scale_nBARS_OBJECTIVE "0" ;
#     nidash:Barnes_Scale_nBARS_SUBJECTIVE_AWARENESS "0" ;
#     nidash:Barnes_Scale_nBARS_SUBJECTIVE_DISTRESS "0" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_001312253228_0001 .
#
# nidash:CGI_001312253228_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:CGIDataStructure,
#         prov:Entity ;
#     nidash:CGI_nCGI1 "5" ;
#     nidash:CGI_nCGI2 "3" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_001312253228_0001 .
#
# nidash:Calgary_001312253228_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:CalgaryDataStructure,
#         prov:Entity ;
#     nidash:Calgary_Depression_Index_nCD_DEPRESSION "1" ;
#     nidash:Calgary_Depression_Index_nCD_EARLY_WAKING "0" ;
#     nidash:Calgary_Depression_Index_nCD_GUILT_PATHOLOGICAL "0" ;
#     nidash:Calgary_Depression_Index_nCD_GUILT_REFERENCE "0" ;
#     nidash:Calgary_Depression_Index_nCD_HOPELESSNESS "0" ;
#     nidash:Calgary_Depression_Index_nCD_MORNING_DEPRESSION "0" ;
#     nidash:Calgary_Depression_Index_nCD_OBSERVED_DEPRESSION "2" ;
#     nidash:Calgary_Depression_Index_nCD_SELF_DEPRICATION "0" ;
#     nidash:Calgary_Depression_Index_nCD_SUICIDE "0" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_001312253228_0001 .
#
# nidash:Card_000966724198_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:CardDataStructure,
#         prov:Entity ;
#     nidash:Card_Sorting_Test_CMINDS_Completed_Categories "3" ;
#     nidash:Card_Sorting_Test_CMINDS_Conceptual_Level "30" ;
#     nidash:Card_Sorting_Test_CMINDS_Learning_to_Learn "-19.23077" ;
#     nidash:Card_Sorting_Test_CMINDS_Maintain_Set_Failure "0" ;
#     nidash:Card_Sorting_Test_CMINDS_Nonperseverative_Errors "7" ;
#     nidash:Card_Sorting_Test_CMINDS_Number_of_Trials "47" ;
#     nidash:Card_Sorting_Test_CMINDS_Percent_Conceptual_Level "64" ;
#     nidash:Card_Sorting_Test_CMINDS_Percent_Errors "23" ;
#     nidash:Card_Sorting_Test_CMINDS_Percent_Nonperseverative_Errors "15" ;
#     nidash:Card_Sorting_Test_CMINDS_Percent_Perseverative_Errors "9" ;
#     nidash:Card_Sorting_Test_CMINDS_Percent_Perseverative_Responses "9" ;
#     nidash:Card_Sorting_Test_CMINDS_Perseverative_Errors "4" ;
#     nidash:Card_Sorting_Test_CMINDS_Perseverative_Responses "4" ;
#     nidash:Card_Sorting_Test_CMINDS_Total_Correct "36" ;
#     nidash:Card_Sorting_Test_CMINDS_Total_Errors "11" ;
#     nidash:Card_Sorting_Test_CMINDS_Trials_to_Complete_Category_1 "10" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_000966724198_0001 .
#
# nidash:Card_001312253228_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:CardDataStructure,
#         prov:Entity ;
#     nidash:Card_Sorting_Test_CMINDS_Completed_Categories "3" ;
#     nidash:Card_Sorting_Test_CMINDS_Conceptual_Level "45" ;
#     nidash:Card_Sorting_Test_CMINDS_Learning_to_Learn "-6.37255" ;
#     nidash:Card_Sorting_Test_CMINDS_Maintain_Set_Failure "2" ;
#     nidash:Card_Sorting_Test_CMINDS_Nonperseverative_Errors "7" ;
#     nidash:Card_Sorting_Test_CMINDS_Number_of_Trials "57" ;
#     nidash:Card_Sorting_Test_CMINDS_Percent_Conceptual_Level "79" ;
#     nidash:Card_Sorting_Test_CMINDS_Percent_Errors "18" ;
#     nidash:Card_Sorting_Test_CMINDS_Percent_Nonperseverative_Errors "12" ;
#     nidash:Card_Sorting_Test_CMINDS_Percent_Perseverative_Errors "5" ;
#     nidash:Card_Sorting_Test_CMINDS_Percent_Perseverative_Responses "5" ;
#     nidash:Card_Sorting_Test_CMINDS_Perseverative_Errors "3" ;
#     nidash:Card_Sorting_Test_CMINDS_Perseverative_Responses "3" ;
#     nidash:Card_Sorting_Test_CMINDS_Total_Correct "47" ;
#     nidash:Card_Sorting_Test_CMINDS_Total_Errors "10" ;
#     nidash:Card_Sorting_Test_CMINDS_Trials_to_Complete_Category_1 "12" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_001312253228_0001 .
#
# nidash:Card_001312445276_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:CardDataStructure,
#         prov:Entity ;
#     nidash:Card_Sorting_Test_CMINDS_Completed_Categories "3" ;
#     nidash:Card_Sorting_Test_CMINDS_Conceptual_Level "30" ;
#     nidash:Card_Sorting_Test_CMINDS_Learning_to_Learn "3.787879" ;
#     nidash:Card_Sorting_Test_CMINDS_Maintain_Set_Failure "0" ;
#     nidash:Card_Sorting_Test_CMINDS_Nonperseverative_Errors "2" ;
#     nidash:Card_Sorting_Test_CMINDS_Number_of_Trials "34" ;
#     nidash:Card_Sorting_Test_CMINDS_Percent_Conceptual_Level "88" ;
#     nidash:Card_Sorting_Test_CMINDS_Percent_Errors "12" ;
#     nidash:Card_Sorting_Test_CMINDS_Percent_Nonperseverative_Errors "6" ;
#     nidash:Card_Sorting_Test_CMINDS_Percent_Perseverative_Errors "6" ;
#     nidash:Card_Sorting_Test_CMINDS_Percent_Perseverative_Responses "6" ;
#     nidash:Card_Sorting_Test_CMINDS_Perseverative_Errors "2" ;
#     nidash:Card_Sorting_Test_CMINDS_Perseverative_Responses "2" ;
#     nidash:Card_Sorting_Test_CMINDS_Total_Correct "30" ;
#     nidash:Card_Sorting_Test_CMINDS_Total_Errors "4" ;
#     nidash:Card_Sorting_Test_CMINDS_Trials_to_Complete_Category_1 "12" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_001312445276_0001 .
#
# nidash:Category_000966724198_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:CategoryDataStructure,
#         prov:Entity ;
#     nidash:Category_Fluency_Test_CMINDS_In_Set_1 "26" ;
#     nidash:Category_Fluency_Test_CMINDS_In_Set_2 "18" ;
#     nidash:Category_Fluency_Test_CMINDS_In_Set_3 "20" ;
#     nidash:Category_Fluency_Test_CMINDS_Total_In_Set "64" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_000966724198_0001 .
#
# nidash:Category_001312253228_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:CategoryDataStructure,
#         prov:Entity ;
#     nidash:Category_Fluency_Test_CMINDS_In_Set_1 "26" ;
#     nidash:Category_Fluency_Test_CMINDS_In_Set_2 "17" ;
#     nidash:Category_Fluency_Test_CMINDS_In_Set_3 "13" ;
#     nidash:Category_Fluency_Test_CMINDS_Total_In_Set "56" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_001312253228_0001 .
#
# nidash:Category_001312445276_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:CategoryDataStructure,
#         prov:Entity ;
#     nidash:Category_Fluency_Test_CMINDS_In_Set_1 "17" ;
#     nidash:Category_Fluency_Test_CMINDS_In_Set_2 "16" ;
#     nidash:Category_Fluency_Test_CMINDS_In_Set_3 "22" ;
#     nidash:Category_Fluency_Test_CMINDS_Total_In_Set "55" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_001312445276_0001 .
#
# nidash:Combined_001312253228_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:CombinedDataStructure,
#         prov:Entity ;
#     nidash:Combined_Assessment_nNSA_Global_Negative_Symptoms_Rating "2" ;
#     nidash:Combined_Assessment_nNSA_Reduced_Emotion "4" ;
#     nidash:Combined_Assessment_nNSA_Reduced_Interests "1" ;
#     nidash:Combined_Assessment_nNSA_Reduced_Social_Drive "4" ;
#     nidash:Combined_Assessment_nNSA_Restricted_Speech_Qty "2" ;
#     nidash:Combined_Assessment_nPANSS_ABSTRACT_THINKING "1" ;
#     nidash:Combined_Assessment_nPANSS_ANXIETY "1" ;
#     nidash:Combined_Assessment_nPANSS_ATTENTION "2" ;
#     nidash:Combined_Assessment_nPANSS_BLUNTED_AFFECT "1" ;
#     nidash:Combined_Assessment_nPANSS_CONCEPTUAL_DISORGANIZATION "2" ;
#     nidash:Combined_Assessment_nPANSS_DELUSIONS "1" ;
#     nidash:Combined_Assessment_nPANSS_DEPRESSION "2" ;
#     nidash:Combined_Assessment_nPANSS_DISORIENTATION "1" ;
#     nidash:Combined_Assessment_nPANSS_EMOTIONAL_WITHDRAWAL "3" ;
#     nidash:Combined_Assessment_nPANSS_EXCITEMENT "2" ;
#     nidash:Combined_Assessment_nPANSS_GRANDIOSITY "1" ;
#     nidash:Combined_Assessment_nPANSS_GUILT_FEELINGS "1" ;
#     nidash:Combined_Assessment_nPANSS_HALLUCINATORY_BEHAVIOR "4" ;
#     nidash:Combined_Assessment_nPANSS_HOSTILITY "1" ;
#     nidash:Combined_Assessment_nPANSS_IMPULSE "1" ;
#     nidash:Combined_Assessment_nPANSS_JUDGMENT "1" ;
#     nidash:Combined_Assessment_nPANSS_MANNERISIM "2" ;
#     nidash:Combined_Assessment_nPANSS_MOTOR_RETARDATION "1" ;
#     nidash:Combined_Assessment_nPANSS_POOR_RAPPORT "1" ;
#     nidash:Combined_Assessment_nPANSS_PREOCCUPATION "1" ;
#     nidash:Combined_Assessment_nPANSS_SOCIAL_AVOIDANCE "2" ;
#     nidash:Combined_Assessment_nPANSS_SOMATIC_CONCERN "1" ;
#     nidash:Combined_Assessment_nPANSS_SPONTANEITY "3" ;
#     nidash:Combined_Assessment_nPANSS_STEREOTYPED_THINKING "2" ;
#     nidash:Combined_Assessment_nPANSS_SUSPICIOUSNESS "1" ;
#     nidash:Combined_Assessment_nPANSS_TENSION "1" ;
#     nidash:Combined_Assessment_nPANSS_UNCOOPERATIVE "1" ;
#     nidash:Combined_Assessment_nPANSS_UNUSUAL_THOUGHT "2" ;
#     nidash:Combined_Assessment_nPANSS_VOLITION "1" ;
#     nidash:Combined_Assessment_nPANSS_WITHDRAWAL "1" ;
#     nidash:Combined_Assessment_nSANS_AFFECTIVE_FLATTENING "1" ;
#     nidash:Combined_Assessment_nSANS_AFFECTIVE_NONRESPONSE "2" ;
#     nidash:Combined_Assessment_nSANS_ALOGIA "2" ;
#     nidash:Combined_Assessment_nSANS_ANERGIA "2" ;
#     nidash:Combined_Assessment_nSANS_ANHEDONIA "0" ;
#     nidash:Combined_Assessment_nSANS_ATTENTION "0" ;
#     nidash:Combined_Assessment_nSANS_AVOLITION "1" ;
#     nidash:Combined_Assessment_nSANS_BLOCKING "0" ;
#     nidash:Combined_Assessment_nSANS_EXPRESSIVE "2" ;
#     nidash:Combined_Assessment_nSANS_EYE_CONTACT "2" ;
#     nidash:Combined_Assessment_nSANS_FACIAL "2" ;
#     nidash:Combined_Assessment_nSANS_HYGIENE "1" ;
#     nidash:Combined_Assessment_nSANS_IMPERSISTENCE "2" ;
#     nidash:Combined_Assessment_nSANS_INAPPROPRIATE_AFFECT "0" ;
#     nidash:Combined_Assessment_nSANS_INTIMACY "0" ;
#     nidash:Combined_Assessment_nSANS_MENTAL_TESTING "0" ;
#     nidash:Combined_Assessment_nSANS_RECREATION "0" ;
#     nidash:Combined_Assessment_nSANS_RELATIONSHIPS "4" ;
#     nidash:Combined_Assessment_nSANS_RESPONSE_LATENCY "2" ;
#     nidash:Combined_Assessment_nSANS_SEXUAL "3" ;
#     nidash:Combined_Assessment_nSANS_SOCIAL_INATTENTIVENESS "0" ;
#     nidash:Combined_Assessment_nSANS_SPEECH "2" ;
#     nidash:Combined_Assessment_nSANS_SPEECH_CONTENT "1" ;
#     nidash:Combined_Assessment_nSANS_SPONTANEOUS "2" ;
#     nidash:Combined_Assessment_nSANS_VOCAL_INFLECTIONS "1" ;
#     nidash:Combined_Assessment_nSAPS_AGGRESSIVE_BEHAVIOR "0" ;
#     nidash:Combined_Assessment_nSAPS_APPEARANCE "0" ;
#     nidash:Combined_Assessment_nSAPS_AUDITORY_HALLUCINATIONS "5" ;
#     nidash:Combined_Assessment_nSAPS_CIRCUMSTANTIALITY "0" ;
#     nidash:Combined_Assessment_nSAPS_CLANGING "0" ;
#     nidash:Combined_Assessment_nSAPS_CONTROLLED_DELUSIONS "2" ;
#     nidash:Combined_Assessment_nSAPS_DERAILMENT "2" ;
#     nidash:Combined_Assessment_nSAPS_DISTRACTIBLE_SPEECH "0" ;
#     nidash:Combined_Assessment_nSAPS_GLOBAL_BEHAVIOR "0" ;
#     nidash:Combined_Assessment_nSAPS_GLOBAL_DELUSIONS "0" ;
#     nidash:Combined_Assessment_nSAPS_GLOBAL_HALLUCINATIONS "4" ;
#     nidash:Combined_Assessment_nSAPS_GLOBAL_THOUGHT_DISORDER "0" ;
#     nidash:Combined_Assessment_nSAPS_GRANDIOSE_DELUSIONS "0" ;
#     nidash:Combined_Assessment_nSAPS_GUILT_DELUSIONS "0" ;
#     nidash:Combined_Assessment_nSAPS_ILLOGICALITY "0" ;
#     nidash:Combined_Assessment_nSAPS_INCOHERENCE "0" ;
#     nidash:Combined_Assessment_nSAPS_JEALOSY_DELUSIONS "0" ;
#     nidash:Combined_Assessment_nSAPS_MIND_READING_DELUSIONS "0" ;
#     nidash:Combined_Assessment_nSAPS_OLFACTORY_HALLUCINATIONS "0" ;
#     nidash:Combined_Assessment_nSAPS_PERSECUTORY_DELUSIONS "1" ;
#     nidash:Combined_Assessment_nSAPS_PRESSURE_SPEECH "0" ;
#     nidash:Combined_Assessment_nSAPS_REFERENCE_DELUSIONS "1" ;
#     nidash:Combined_Assessment_nSAPS_RELIGIOUS_DELUSIONS "0" ;
#     nidash:Combined_Assessment_nSAPS_REPETITIVE_BEHAVIOR "0" ;
#     nidash:Combined_Assessment_nSAPS_SOCIAL_BEHAVIOR "0" ;
#     nidash:Combined_Assessment_nSAPS_SOMATIC_DELUSIONS "0" ;
#     nidash:Combined_Assessment_nSAPS_TACTILE_HALLUCINATIONS "0" ;
#     nidash:Combined_Assessment_nSAPS_TANGENTIALITY "0" ;
#     nidash:Combined_Assessment_nSAPS_THOUGHT_BROADCASTING "0" ;
#     nidash:Combined_Assessment_nSAPS_THOUGHT_INSERTION "0" ;
#     nidash:Combined_Assessment_nSAPS_THOUGHT_WITHDRAWAL "0" ;
#     nidash:Combined_Assessment_nSAPS_VISUAL_HALLUCINATIONS "0" ;
#     nidash:Combined_Assessment_nSAPS_VOICES_COMMENTING "5" ;
#     nidash:Combined_Assessment_nSAPS_VOICES_CONVERSING "0" ;
#     nidash:Combined_Assessment_nSDS_CATEGORIZATION "3" ;
#     nidash:Combined_Assessment_nSDS_CRITERIA_PRIMARY "9" ;
#     nidash:Combined_Assessment_nSDS_CRITERIA_SEVERITY "1" ;
#     nidash:Combined_Assessment_nSDS_CRITERIA_STABLE "1" ;
#     nidash:Combined_Assessment_nSDS_DSM_III_R "2" ;
#     nidash:Combined_Assessment_nSDS_PRIMARY_AFFECT "9" ;
#     nidash:Combined_Assessment_nSDS_PRIMARY_EMOTIONAL "9" ;
#     nidash:Combined_Assessment_nSDS_PRIMARY_INTERESTS "9" ;
#     nidash:Combined_Assessment_nSDS_PRIMARY_PURPOSE "2" ;
#     nidash:Combined_Assessment_nSDS_PRIMARY_SOCIAL "2" ;
#     nidash:Combined_Assessment_nSDS_PRIMARY_SPEECH "9" ;
#     nidash:Combined_Assessment_nSDS_SEVERITY_AFFECT "1" ;
#     nidash:Combined_Assessment_nSDS_SEVERITY_EMOTIONAL "1" ;
#     nidash:Combined_Assessment_nSDS_SEVERITY_INTERESTS "0" ;
#     nidash:Combined_Assessment_nSDS_SEVERITY_PURPOSE "0" ;
#     nidash:Combined_Assessment_nSDS_SEVERITY_SOCIAL "2" ;
#     nidash:Combined_Assessment_nSDS_SEVERITY_SPEECH "1" ;
#     nidash:Combined_Assessment_nSDS_STABLE_AFFECT "9" ;
#     nidash:Combined_Assessment_nSDS_STABLE_EMOTIONAL "9" ;
#     nidash:Combined_Assessment_nSDS_STABLE_INTERESTS "9" ;
#     nidash:Combined_Assessment_nSDS_STABLE_PURPOSE "9" ;
#     nidash:Combined_Assessment_nSDS_STABLE_SOCIAL "2" ;
#     nidash:Combined_Assessment_nSDS_STABLE_SPEECH "9" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_001312253228_0001 .
#
# nidash:Continuous_000966724198_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:ContinuousDataStructure,
#         prov:Entity ;
#     nidash:Continuous_Performance_Test_CMINDS_Mean_DPrime_AtoC "2.54" ;
#     nidash:Continuous_Performance_Test_CMINDS_Mean_RT_AtoC "439" ;
#     nidash:Continuous_Performance_Test_CMINDS_Total_False_Hit "18" ;
#     nidash:Continuous_Performance_Test_CMINDS_Total_Hit_Target "82" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_000966724198_0001 .
#
# nidash:Continuous_001312253228_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:ContinuousDataStructure,
#         prov:Entity ;
#     nidash:Continuous_Performance_Test_CMINDS_Mean_DPrime_AtoC "3.38" ;
#     nidash:Continuous_Performance_Test_CMINDS_Mean_RT_AtoC "645" ;
#     nidash:Continuous_Performance_Test_CMINDS_Total_False_Hit "4" ;
#     nidash:Continuous_Performance_Test_CMINDS_Total_Hit_Target "80" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_001312253228_0001 .
#
# nidash:Continuous_001312445276_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:ContinuousDataStructure,
#         prov:Entity ;
#     nidash:Continuous_Performance_Test_CMINDS_Mean_DPrime_AtoC "3.84" ;
#     nidash:Continuous_Performance_Test_CMINDS_Mean_RT_AtoC "502" ;
#     nidash:Continuous_Performance_Test_CMINDS_Total_False_Hit "3" ;
#     nidash:Continuous_Performance_Test_CMINDS_Total_Hit_Target "88" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_001312445276_0001 .
#
# nidash:DelayedVisual_000966724198_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:DelayedVisualDataStructure,
#         prov:Entity ;
#     nidash:Delayed_Visual_Figural_Learning_Test_CMINDS_Correct_Recognition "11" ;
#     nidash:Delayed_Visual_Figural_Learning_Test_CMINDS_Hit_Target_Recognition "6" ;
#     nidash:Delayed_Visual_Figural_Learning_Test_CMINDS_Max_RT_Correct_Recognition "1235" ;
#     nidash:Delayed_Visual_Figural_Learning_Test_CMINDS_Med_RT_Correct_Recognition "930" ;
#     nidash:Delayed_Visual_Figural_Learning_Test_CMINDS_Min_RT_Correct_Recognition "718" ;
#     nidash:Delayed_Visual_Figural_Learning_Test_CMINDS_Percent_Retention_Delay_Recall "91" ;
#     nidash:Delayed_Visual_Figural_Learning_Test_CMINDS_Score_Delay_Recall "10" ;
#     nidash:Delayed_Visual_Figural_Learning_Test_CMINDS_Std_Dev_RT_Correct_Recognition "167" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_000966724198_0001 .
#
# nidash:DelayedVisual_001312253228_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:DelayedVisualDataStructure,
#         prov:Entity ;
#     nidash:Delayed_Visual_Figural_Learning_Test_CMINDS_Correct_Recognition "11" ;
#     nidash:Delayed_Visual_Figural_Learning_Test_CMINDS_Hit_Target_Recognition "5" ;
#     nidash:Delayed_Visual_Figural_Learning_Test_CMINDS_Max_RT_Correct_Recognition "1844" ;
#     nidash:Delayed_Visual_Figural_Learning_Test_CMINDS_Med_RT_Correct_Recognition "1328" ;
#     nidash:Delayed_Visual_Figural_Learning_Test_CMINDS_Min_RT_Correct_Recognition "844" ;
#     nidash:Delayed_Visual_Figural_Learning_Test_CMINDS_Percent_Retention_Delay_Recall "100" ;
#     nidash:Delayed_Visual_Figural_Learning_Test_CMINDS_Score_Delay_Recall "8" ;
#     nidash:Delayed_Visual_Figural_Learning_Test_CMINDS_Std_Dev_RT_Correct_Recognition "333" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_001312253228_0001 .
#
# nidash:DelayedVisual_001312445276_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:DelayedVisualDataStructure,
#         prov:Entity ;
#     nidash:Delayed_Visual_Figural_Learning_Test_CMINDS_Correct_Recognition "11" ;
#     nidash:Delayed_Visual_Figural_Learning_Test_CMINDS_Hit_Target_Recognition "6" ;
#     nidash:Delayed_Visual_Figural_Learning_Test_CMINDS_Max_RT_Correct_Recognition "2469" ;
#     nidash:Delayed_Visual_Figural_Learning_Test_CMINDS_Med_RT_Correct_Recognition "1078" ;
#     nidash:Delayed_Visual_Figural_Learning_Test_CMINDS_Min_RT_Correct_Recognition "750" ;
#     nidash:Delayed_Visual_Figural_Learning_Test_CMINDS_Percent_Retention_Delay_Recall "100" ;
#     nidash:Delayed_Visual_Figural_Learning_Test_CMINDS_Score_Delay_Recall "12" ;
#     nidash:Delayed_Visual_Figural_Learning_Test_CMINDS_Std_Dev_RT_Correct_Recognition "516" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_001312445276_0001 .
#
# nidash:Delayed_000966724198_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:DelayedDataStructure,
#         prov:Entity ;
#     nidash:Delayed_Semantic_Verbal_Learning_Test_CMINDS_Correct_Delay_Recall "9" ;
#     nidash:Delayed_Semantic_Verbal_Learning_Test_CMINDS_Elapsed_Time_Delay "33" ;
#     nidash:Delayed_Semantic_Verbal_Learning_Test_CMINDS_Hit_Target_Recognition "10" ;
#     nidash:Delayed_Semantic_Verbal_Learning_Test_CMINDS_Max_Correct_RT_Recognition "1469" ;
#     nidash:Delayed_Semantic_Verbal_Learning_Test_CMINDS_Mean_RT_Recognition "1013" ;
#     nidash:Delayed_Semantic_Verbal_Learning_Test_CMINDS_Med_Correct_RT_Recognition "953" ;
#     nidash:Delayed_Semantic_Verbal_Learning_Test_CMINDS_Min_Correct_RT_Recognition "766" ;
#     nidash:Delayed_Semantic_Verbal_Learning_Test_CMINDS_Std_Dev_Correct_RT_Recognition "195" ;
#     nidash:Delayed_Semantic_Verbal_Learning_Test_CMINDS_Total_Correct_Recognition "21" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_000966724198_0001 .
#
# nidash:Delayed_001312253228_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:DelayedDataStructure,
#         prov:Entity ;
#     nidash:Delayed_Semantic_Verbal_Learning_Test_CMINDS_Correct_Delay_Recall "4" ;
#     nidash:Delayed_Semantic_Verbal_Learning_Test_CMINDS_Elapsed_Time_Delay "27" ;
#     nidash:Delayed_Semantic_Verbal_Learning_Test_CMINDS_Hit_Target_Recognition "10" ;
#     nidash:Delayed_Semantic_Verbal_Learning_Test_CMINDS_Max_Correct_RT_Recognition "1766" ;
#     nidash:Delayed_Semantic_Verbal_Learning_Test_CMINDS_Mean_RT_Recognition "1292" ;
#     nidash:Delayed_Semantic_Verbal_Learning_Test_CMINDS_Med_Correct_RT_Recognition "1196" ;
#     nidash:Delayed_Semantic_Verbal_Learning_Test_CMINDS_Min_Correct_RT_Recognition "1015" ;
#     nidash:Delayed_Semantic_Verbal_Learning_Test_CMINDS_Std_Dev_Correct_RT_Recognition "231" ;
#     nidash:Delayed_Semantic_Verbal_Learning_Test_CMINDS_Total_Correct_Recognition "22" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_001312253228_0001 .
#
# nidash:Delayed_001312445276_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:DelayedDataStructure,
#         prov:Entity ;
#     nidash:Delayed_Semantic_Verbal_Learning_Test_CMINDS_Correct_Delay_Recall "10" ;
#     nidash:Delayed_Semantic_Verbal_Learning_Test_CMINDS_Elapsed_Time_Delay "25" ;
#     nidash:Delayed_Semantic_Verbal_Learning_Test_CMINDS_Hit_Target_Recognition "12" ;
#     nidash:Delayed_Semantic_Verbal_Learning_Test_CMINDS_Max_Correct_RT_Recognition "1765" ;
#     nidash:Delayed_Semantic_Verbal_Learning_Test_CMINDS_Mean_RT_Recognition "1091" ;
#     nidash:Delayed_Semantic_Verbal_Learning_Test_CMINDS_Med_Correct_RT_Recognition "976" ;
#     nidash:Delayed_Semantic_Verbal_Learning_Test_CMINDS_Min_Correct_RT_Recognition "828" ;
#     nidash:Delayed_Semantic_Verbal_Learning_Test_CMINDS_Std_Dev_Correct_RT_Recognition "263" ;
#     nidash:Delayed_Semantic_Verbal_Learning_Test_CMINDS_Total_Correct_Recognition "24" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_001312445276_0001 .
#
# nidash:Demographics_000966724198_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:DemographicsDataStructure,
#         prov:Entity ;
#     nidash:Demographics_dDEMOG_ANTIEPS_START "." ;
#     nidash:Demographics_dDEMOG_CUR_ANTIPSYCHOTIC_START "." ;
#     nidash:Demographics_dDEMOG_FIRST_ANTIPSYCHOTIC_START "." ;
#     nidash:Demographics_nDEMOG_AGE_HOSPITALIZATION "." ;
#     nidash:Demographics_nDEMOG_AGE_ONSET_PREDROMAL "." ;
#     nidash:Demographics_nDEMOG_AGE_ONSET_PSYCHOTIC "." ;
#     nidash:Demographics_nDEMOG_ANTIDEPRESSANT "." ;
#     nidash:Demographics_nDEMOG_ANTIEPS "." ;
#     nidash:Demographics_nDEMOG_BMI "32.9" ;
#     nidash:Demographics_nDEMOG_CURRENT_ANTIPSYCHOTIC "." ;
#     nidash:Demographics_nDEMOG_CUR_AGE "54" ;
#     nidash:Demographics_nDEMOG_DIAGNOSIS "2" ;
#     nidash:Demographics_nDEMOG_ETHNICITY "0" ;
#     nidash:Demographics_nDEMOG_FIRST_ANTIPSYCHOTIC_AGE "." ;
#     nidash:Demographics_nDEMOG_HEIGHT "62" ;
#     nidash:Demographics_nDEMOG_HOSPITALIZATIONS_NUMBER "." ;
#     nidash:Demographics_nDEMOG_MARITAL "1" ;
#     nidash:Demographics_nDEMOG_MOOD "." ;
#     nidash:Demographics_nDEMOG_RACE "5" ;
#     nidash:Demographics_nDEMOG_RELATIVE_PSYCHOSIS "." ;
#     nidash:Demographics_nDEMOG_SUICIDE_ATTEMPTS "." ;
#     nidash:Demographics_nDEMOG_TYPE "." ;
#     nidash:Demographics_nDEMOG_WEIGHT "180" ;
#     nidash:Demographics_sDEMOG_ANTIDEPRESSANT_DOSE "" ;
#     nidash:Demographics_sDEMOG_ANTIDEPRESSANT_DRUG "" ;
#     nidash:Demographics_sDEMOG_ANTIEPS_DOSE "" ;
#     nidash:Demographics_sDEMOG_ANTIEPS_DRUG "" ;
#     nidash:Demographics_sDEMOG_BP "124/68" ;
#     nidash:Demographics_sDEMOG_CUR_ANTIPSYCHOTIC_DOSE "" ;
#     nidash:Demographics_sDEMOG_CUR_ANTIPSYCHOTIC_DRUG "" ;
#     nidash:Demographics_sDEMOG_FIRST_ANTIPSYCHOTIC "0" ;
#     nidash:Demographics_sDEMOG_FIRST_ANTIPSYCHOTIC_DRUG "" ;
#     nidash:Demographics_sDEMOG_GENDER "F" ;
#     nidash:Demographics_sDEMOG_HANDEDNESS "R" ;
#     nidash:Demographics_sDEMOG_MOOD_DOSE "" ;
#     nidash:Demographics_sDEMOG_MOOD_DRUG "" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_000966724198_0001 .
#
# nidash:Demographics_001312253228_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:DemographicsDataStructure,
#         prov:Entity ;
#     nidash:Demographics_dDEMOG_ANTIEPS_START "." ;
#     nidash:Demographics_dDEMOG_CUR_ANTIPSYCHOTIC_START "01/01/1995" ;
#     nidash:Demographics_dDEMOG_FIRST_ANTIPSYCHOTIC_START "02/01/1990" ;
#     nidash:Demographics_nDEMOG_AGE_HOSPITALIZATION "27" ;
#     nidash:Demographics_nDEMOG_AGE_ONSET_PREDROMAL "24" ;
#     nidash:Demographics_nDEMOG_AGE_ONSET_PSYCHOTIC "27" ;
#     nidash:Demographics_nDEMOG_ANTIDEPRESSANT "0" ;
#     nidash:Demographics_nDEMOG_ANTIEPS "0" ;
#     nidash:Demographics_nDEMOG_BMI "26" ;
#     nidash:Demographics_nDEMOG_CURRENT_ANTIPSYCHOTIC "1" ;
#     nidash:Demographics_nDEMOG_CUR_AGE "47" ;
#     nidash:Demographics_nDEMOG_DIAGNOSIS "1" ;
#     nidash:Demographics_nDEMOG_ETHNICITY "0" ;
#     nidash:Demographics_nDEMOG_FIRST_ANTIPSYCHOTIC_AGE "27" ;
#     nidash:Demographics_nDEMOG_HEIGHT "75" ;
#     nidash:Demographics_nDEMOG_HOSPITALIZATIONS_NUMBER "20" ;
#     nidash:Demographics_nDEMOG_MARITAL "5" ;
#     nidash:Demographics_nDEMOG_MOOD "0" ;
#     nidash:Demographics_nDEMOG_RACE "5" ;
#     nidash:Demographics_nDEMOG_RELATIVE_PSYCHOSIS "1" ;
#     nidash:Demographics_nDEMOG_SUICIDE_ATTEMPTS "0" ;
#     nidash:Demographics_nDEMOG_TYPE "1" ;
#     nidash:Demographics_nDEMOG_WEIGHT "205" ;
#     nidash:Demographics_sDEMOG_ANTIDEPRESSANT_DOSE "" ;
#     nidash:Demographics_sDEMOG_ANTIDEPRESSANT_DRUG "" ;
#     nidash:Demographics_sDEMOG_ANTIEPS_DOSE "" ;
#     nidash:Demographics_sDEMOG_ANTIEPS_DRUG "" ;
#     nidash:Demographics_sDEMOG_BP "141/92" ;
#     nidash:Demographics_sDEMOG_CUR_ANTIPSYCHOTIC_DOSE "450" ;
#     nidash:Demographics_sDEMOG_CUR_ANTIPSYCHOTIC_DRUG "Clozaril" ;
#     nidash:Demographics_sDEMOG_FIRST_ANTIPSYCHOTIC "1" ;
#     nidash:Demographics_sDEMOG_FIRST_ANTIPSYCHOTIC_DRUG "Thorazine" ;
#     nidash:Demographics_sDEMOG_GENDER "M" ;
#     nidash:Demographics_sDEMOG_HANDEDNESS "R" ;
#     nidash:Demographics_sDEMOG_MOOD_DOSE "" ;
#     nidash:Demographics_sDEMOG_MOOD_DRUG "" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_001312253228_0001 .
#
# nidash:Demographics_001312445276_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:DemographicsDataStructure,
#         prov:Entity ;
#     nidash:Demographics_dDEMOG_ANTIEPS_START "." ;
#     nidash:Demographics_dDEMOG_CUR_ANTIPSYCHOTIC_START "." ;
#     nidash:Demographics_dDEMOG_FIRST_ANTIPSYCHOTIC_START "." ;
#     nidash:Demographics_nDEMOG_AGE_HOSPITALIZATION "." ;
#     nidash:Demographics_nDEMOG_AGE_ONSET_PREDROMAL "." ;
#     nidash:Demographics_nDEMOG_AGE_ONSET_PSYCHOTIC "." ;
#     nidash:Demographics_nDEMOG_ANTIDEPRESSANT "." ;
#     nidash:Demographics_nDEMOG_ANTIEPS "." ;
#     nidash:Demographics_nDEMOG_BMI "23.8" ;
#     nidash:Demographics_nDEMOG_CURRENT_ANTIPSYCHOTIC "." ;
#     nidash:Demographics_nDEMOG_CUR_AGE "29" ;
#     nidash:Demographics_nDEMOG_DIAGNOSIS "2" ;
#     nidash:Demographics_nDEMOG_ETHNICITY "0" ;
#     nidash:Demographics_nDEMOG_FIRST_ANTIPSYCHOTIC_AGE "." ;
#     nidash:Demographics_nDEMOG_HEIGHT "67" ;
#     nidash:Demographics_nDEMOG_HOSPITALIZATIONS_NUMBER "." ;
#     nidash:Demographics_nDEMOG_MARITAL "5" ;
#     nidash:Demographics_nDEMOG_MOOD "." ;
#     nidash:Demographics_nDEMOG_RACE "3" ;
#     nidash:Demographics_nDEMOG_RELATIVE_PSYCHOSIS "." ;
#     nidash:Demographics_nDEMOG_SUICIDE_ATTEMPTS "." ;
#     nidash:Demographics_nDEMOG_TYPE "." ;
#     nidash:Demographics_nDEMOG_WEIGHT "152" ;
#     nidash:Demographics_sDEMOG_ANTIDEPRESSANT_DOSE "" ;
#     nidash:Demographics_sDEMOG_ANTIDEPRESSANT_DRUG "" ;
#     nidash:Demographics_sDEMOG_ANTIEPS_DOSE "" ;
#     nidash:Demographics_sDEMOG_ANTIEPS_DRUG "" ;
#     nidash:Demographics_sDEMOG_BP "135/78" ;
#     nidash:Demographics_sDEMOG_CUR_ANTIPSYCHOTIC_DOSE "" ;
#     nidash:Demographics_sDEMOG_CUR_ANTIPSYCHOTIC_DRUG "" ;
#     nidash:Demographics_sDEMOG_FIRST_ANTIPSYCHOTIC "0" ;
#     nidash:Demographics_sDEMOG_FIRST_ANTIPSYCHOTIC_DRUG "" ;
#     nidash:Demographics_sDEMOG_GENDER "F" ;
#     nidash:Demographics_sDEMOG_HANDEDNESS "R" ;
#     nidash:Demographics_sDEMOG_MOOD_DOSE "" ;
#     nidash:Demographics_sDEMOG_MOOD_DRUG "" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_001312445276_0001 .
#
# nidash:Edinburgh_000966724198_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:EdinburghDataStructure,
#         prov:Entity ;
#     nidash:Edinburgh_Handedness_nHAND_BOX "1" ;
#     nidash:Edinburgh_Handedness_nHAND_BROOM "2" ;
#     nidash:Edinburgh_Handedness_nHAND_DRAWING "2" ;
#     nidash:Edinburgh_Handedness_nHAND_KNIFE "2" ;
#     nidash:Edinburgh_Handedness_nHAND_MATCH "2" ;
#     nidash:Edinburgh_Handedness_nHAND_SCISSORS "0" ;
#     nidash:Edinburgh_Handedness_nHAND_SPOON "-1" ;
#     nidash:Edinburgh_Handedness_nHAND_THROWING "1" ;
#     nidash:Edinburgh_Handedness_nHAND_TOOTHBRUSH "0" ;
#     nidash:Edinburgh_Handedness_nHAND_WRITING "1" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_000966724198_0001 .
#
# nidash:Edinburgh_001312253228_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:EdinburghDataStructure,
#         prov:Entity ;
#     nidash:Edinburgh_Handedness_nHAND_BOX "2" ;
#     nidash:Edinburgh_Handedness_nHAND_BROOM "2" ;
#     nidash:Edinburgh_Handedness_nHAND_DRAWING "2" ;
#     nidash:Edinburgh_Handedness_nHAND_KNIFE "2" ;
#     nidash:Edinburgh_Handedness_nHAND_MATCH "2" ;
#     nidash:Edinburgh_Handedness_nHAND_SCISSORS "2" ;
#     nidash:Edinburgh_Handedness_nHAND_SPOON "2" ;
#     nidash:Edinburgh_Handedness_nHAND_THROWING "2" ;
#     nidash:Edinburgh_Handedness_nHAND_TOOTHBRUSH "2" ;
#     nidash:Edinburgh_Handedness_nHAND_WRITING "2" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_001312253228_0001 .
#
# nidash:Edinburgh_001312445276_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:EdinburghDataStructure,
#         prov:Entity ;
#     nidash:Edinburgh_Handedness_nHAND_BOX "2" ;
#     nidash:Edinburgh_Handedness_nHAND_BROOM "2" ;
#     nidash:Edinburgh_Handedness_nHAND_DRAWING "2" ;
#     nidash:Edinburgh_Handedness_nHAND_KNIFE "2" ;
#     nidash:Edinburgh_Handedness_nHAND_MATCH "-2" ;
#     nidash:Edinburgh_Handedness_nHAND_SCISSORS "2" ;
#     nidash:Edinburgh_Handedness_nHAND_SPOON "2" ;
#     nidash:Edinburgh_Handedness_nHAND_THROWING "2" ;
#     nidash:Edinburgh_Handedness_nHAND_TOOTHBRUSH "2" ;
#     nidash:Edinburgh_Handedness_nHAND_WRITING "2" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_001312445276_0001 .
#
# nidash:Facial_000966724198_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:FacialDataStructure,
#         prov:Entity ;
#     nidash:Facial_Emotion_Discrimination_Test_CMINDS_Max_Response_Time "4813" ;
#     nidash:Facial_Emotion_Discrimination_Test_CMINDS_Med_Response_Time "2515" ;
#     nidash:Facial_Emotion_Discrimination_Test_CMINDS_Min_Response_Time "1750" ;
#     nidash:Facial_Emotion_Discrimination_Test_CMINDS_Total_Correct "27" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_000966724198_0001 .
#
# nidash:Facial_001312253228_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:FacialDataStructure,
#         prov:Entity ;
#     nidash:Facial_Emotion_Discrimination_Test_CMINDS_Max_Response_Time "14000" ;
#     nidash:Facial_Emotion_Discrimination_Test_CMINDS_Med_Response_Time "3829" ;
#     nidash:Facial_Emotion_Discrimination_Test_CMINDS_Min_Response_Time "218" ;
#     nidash:Facial_Emotion_Discrimination_Test_CMINDS_Total_Correct "25" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_001312253228_0001 .
#
# nidash:Facial_001312445276_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:FacialDataStructure,
#         prov:Entity ;
#     nidash:Facial_Emotion_Discrimination_Test_CMINDS_Max_Response_Time "4281" ;
#     nidash:Facial_Emotion_Discrimination_Test_CMINDS_Med_Response_Time "1860" ;
#     nidash:Facial_Emotion_Discrimination_Test_CMINDS_Min_Response_Time "1422" ;
#     nidash:Facial_Emotion_Discrimination_Test_CMINDS_Total_Correct "27" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_001312445276_0001 .
#
# nidash:Fagerstrom_000966724198_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:FagerstromDataStructure,
#         prov:Entity ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE1_CIGARETTES "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE1_FROM "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE1_NONSMOKING_FROM "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE1_NONSMOKING_TO "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE1_TO "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE2_CIGARETTES "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE2_FROM "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE2_NONSMOKING_FROM "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE2_NONSMOKING_TO "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE2_TO "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE3_CIGARETTES "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE3_FROM "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE3_NONSMOKING_FROM "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE3_NONSMOKING_TO "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE3_TO "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE4_CIGARETTES "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE4_FROM "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE4_NONSMOKING_FROM "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE4_NONSMOKING_TO "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE4_TO "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE5_CIGARETTES "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE5_FROM "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE5_NONSMOKING_FROM "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE5_NONSMOKING_TO "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE5_TO "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE6_CIGARETTES "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE6_FROM "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE6_NONSMOKING_FROM "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE6_NONSMOKING_TO "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE6_TO "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE7_CIGARETTES "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE7_FROM "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE7_NONSMOKING_FROM "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE7_NONSMOKING_TO "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE7_TO "." ;
#     nidash:Fagerstrom_Smoking_sFAGER_CRAVE "" ;
#     nidash:Fagerstrom_Smoking_sFAGER_FIRST_CIGARETTE "" ;
#     nidash:Fagerstrom_Smoking_sFAGER_NONSMOKER_WHY "Health reasons" ;
#     nidash:Fagerstrom_Smoking_sFAGER_SMOKING_STATUS "Never-smoker" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_000966724198_0001 .
#
# nidash:Fagerstrom_001312253228_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:FagerstromDataStructure,
#         prov:Entity ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE1_CIGARETTES "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE1_FROM "34" ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE1_NONSMOKING_FROM "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE1_NONSMOKING_TO "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE1_TO "47" ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE2_CIGARETTES "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE2_FROM "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE2_NONSMOKING_FROM "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE2_NONSMOKING_TO "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE2_TO "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE3_CIGARETTES "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE3_FROM "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE3_NONSMOKING_FROM "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE3_NONSMOKING_TO "." ;
#     nidash:Fagerstrom_Smoking_nFAGER_PHASE3_TO "." ;
# ...
#     nidash:Simpson_Angus_Rating_Scale_nSIMPSON_SHOULDER "0" ;
#     nidash:Simpson_Angus_Rating_Scale_nSIMPSON_TREMORE_LEFT "0" ;
#     nidash:Simpson_Angus_Rating_Scale_nSIMPSON_TREMOR_OVERALL "0" ;
#     nidash:Simpson_Angus_Rating_Scale_nSIMPSON_TREMOR_RIGHT "0" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_001312253228_0001 .
#
# nidash:Socioeconomic_000966724198_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:SocioeconomicDataStructure,
#         prov:Entity ;
#     nidash:Socioeconomic_Scale_nSES_EDUCATION_PRIME_CARETAKER_18 "3" ;
#     nidash:Socioeconomic_Scale_nSES_EDUCATION_PRIME_CARETAKER_LIFE "0" ;
#     nidash:Socioeconomic_Scale_nSES_EDUCATION_SECOND_CARETAKER_18 "0" ;
#     nidash:Socioeconomic_Scale_nSES_EDUCATION_SECOND_CARETARER_LIFE "0" ;
#     nidash:Socioeconomic_Scale_nSES_EDUCATION_SELF "1" ;
#     nidash:Socioeconomic_Scale_nSES_OCCUPATION_PRIME_CARETAKER_18 "3" ;
#     nidash:Socioeconomic_Scale_nSES_OCCUPATION_PRIME_CARETAKER_LIFE "7" ;
#     nidash:Socioeconomic_Scale_nSES_OCCUPATION_SECOND_CARETAKER_18 "7" ;
#     nidash:Socioeconomic_Scale_nSES_OCCUPATION_SECOND_CARETAKER_LIFE "7" ;
#     nidash:Socioeconomic_Scale_nSES_OCCUPATION_SELF "2" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_000966724198_0001 .
#
# nidash:Socioeconomic_001312253228_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:SocioeconomicDataStructure,
#         prov:Entity ;
#     nidash:Socioeconomic_Scale_nSES_EDUCATION_PRIME_CARETAKER_18 "2" ;
#     nidash:Socioeconomic_Scale_nSES_EDUCATION_PRIME_CARETAKER_LIFE "2" ;
#     nidash:Socioeconomic_Scale_nSES_EDUCATION_SECOND_CARETAKER_18 "2" ;
#     nidash:Socioeconomic_Scale_nSES_EDUCATION_SECOND_CARETARER_LIFE "2" ;
#     nidash:Socioeconomic_Scale_nSES_EDUCATION_SELF "2" ;
#     nidash:Socioeconomic_Scale_nSES_OCCUPATION_PRIME_CARETAKER_18 "3" ;
#     nidash:Socioeconomic_Scale_nSES_OCCUPATION_PRIME_CARETAKER_LIFE "3" ;
#     nidash:Socioeconomic_Scale_nSES_OCCUPATION_SECOND_CARETAKER_18 "3" ;
#     nidash:Socioeconomic_Scale_nSES_OCCUPATION_SECOND_CARETAKER_LIFE "3" ;
#     nidash:Socioeconomic_Scale_nSES_OCCUPATION_SELF "3" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_001312253228_0001 .
#
# nidash:Socioeconomic_001312445276_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:SocioeconomicDataStructure,
#         prov:Entity ;
#     nidash:Socioeconomic_Scale_nSES_EDUCATION_PRIME_CARETAKER_18 "3" ;
#     nidash:Socioeconomic_Scale_nSES_EDUCATION_PRIME_CARETAKER_LIFE "3" ;
#     nidash:Socioeconomic_Scale_nSES_EDUCATION_SECOND_CARETAKER_18 "2" ;
#     nidash:Socioeconomic_Scale_nSES_EDUCATION_SECOND_CARETARER_LIFE "2" ;
#     nidash:Socioeconomic_Scale_nSES_EDUCATION_SELF "2" ;
#     nidash:Socioeconomic_Scale_nSES_OCCUPATION_PRIME_CARETAKER_18 "4" ;
#     nidash:Socioeconomic_Scale_nSES_OCCUPATION_PRIME_CARETAKER_LIFE "4" ;
#     nidash:Socioeconomic_Scale_nSES_OCCUPATION_SECOND_CARETAKER_18 "4" ;
#     nidash:Socioeconomic_Scale_nSES_OCCUPATION_SECOND_CARETAKER_LIFE "4" ;
#     nidash:Socioeconomic_Scale_nSES_OCCUPATION_SELF "4" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_001312445276_0001 .
#
# nidash:Spatial_000966724198_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:SpatialDataStructure,
#         prov:Entity ;
#     nidash:Spatial_Memory_Span_CMINDS_Correct_Forward "8" ;
#     nidash:Spatial_Memory_Span_CMINDS_Correct_Reverse "6" ;
#     nidash:Spatial_Memory_Span_CMINDS_High_Sequence_Forward "6" ;
#     nidash:Spatial_Memory_Span_CMINDS_High_Sequence_Reverse "5" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_000966724198_0001 .
#
# nidash:Spatial_001312253228_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:SpatialDataStructure,
#         prov:Entity ;
#     nidash:Spatial_Memory_Span_CMINDS_Correct_Forward "5" ;
#     nidash:Spatial_Memory_Span_CMINDS_Correct_Reverse "6" ;
#     nidash:Spatial_Memory_Span_CMINDS_High_Sequence_Forward "4" ;
#     nidash:Spatial_Memory_Span_CMINDS_High_Sequence_Reverse "4" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_001312253228_0001 .
#
# nidash:Spatial_001312445276_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:SpatialDataStructure,
#         prov:Entity ;
#     nidash:Spatial_Memory_Span_CMINDS_Correct_Forward "10" ;
#     nidash:Spatial_Memory_Span_CMINDS_Correct_Reverse "7" ;
#     nidash:Spatial_Memory_Span_CMINDS_High_Sequence_Forward "6" ;
#     nidash:Spatial_Memory_Span_CMINDS_High_Sequence_Reverse "5" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_001312445276_0001 .
#
# nidash:Stroop_000966724198_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:StroopDataStructure,
#         prov:Entity ;
#     nidash:Stroop_Test_CMINDS_Elapsed_Time_Read_Color_Name "9.8" ;
#     nidash:Stroop_Test_CMINDS_Elapsed_Time_Say_Color_Square "14.1" ;
#     nidash:Stroop_Test_CMINDS_Elapsed_Time_Say_Color_Word "33.5" ;
#     nidash:Stroop_Test_CMINDS_Elapsed_Time_Say_Non_Color_Word "20" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_000966724198_0001 .
#
# nidash:Stroop_001312253228_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:StroopDataStructure,
#         prov:Entity ;
#     nidash:Stroop_Test_CMINDS_Elapsed_Time_Read_Color_Name "12.5" ;
#     nidash:Stroop_Test_CMINDS_Elapsed_Time_Say_Color_Square "10.9" ;
#     nidash:Stroop_Test_CMINDS_Elapsed_Time_Say_Color_Word "25.8" ;
#     nidash:Stroop_Test_CMINDS_Elapsed_Time_Say_Non_Color_Word "16.7" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_001312253228_0001 .
#
# nidash:Stroop_001312445276_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:StroopDataStructure,
#         prov:Entity ;
#     nidash:Stroop_Test_CMINDS_Elapsed_Time_Read_Color_Name "7.5" ;
#     nidash:Stroop_Test_CMINDS_Elapsed_Time_Say_Color_Square "12.8" ;
#     nidash:Stroop_Test_CMINDS_Elapsed_Time_Say_Color_Word "14.8" ;
#     nidash:Stroop_Test_CMINDS_Elapsed_Time_Say_Non_Color_Word "11.5" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_001312445276_0001 .
#
# nidash:Symbol_000966724198_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:SymbolDataStructure,
#         prov:Entity ;
#     nidash:Symbol_Digit_Association_Test_CMINDS_Correct "45" ;
#     nidash:Symbol_Digit_Association_Test_CMINDS_Incorrect "3" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_000966724198_0001 .
#
# nidash:Symbol_001312253228_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:SymbolDataStructure,
#         prov:Entity ;
#     nidash:Symbol_Digit_Association_Test_CMINDS_Correct "33" ;
#     nidash:Symbol_Digit_Association_Test_CMINDS_Incorrect "0" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_001312253228_0001 .
#
# nidash:Symbol_001312445276_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:SymbolDataStructure,
#         prov:Entity ;
#     nidash:Symbol_Digit_Association_Test_CMINDS_Correct "58" ;
#     nidash:Symbol_Digit_Association_Test_CMINDS_Incorrect "0" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_001312445276_0001 .
#
# nidash:TrailsB_000966724198_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:TrailsBDataStructure,
#         prov:Entity ;
#     nidash:Trails_B_CMINDS_Elapsed_Time_Trails_B "74.9" ;
#     nidash:Trails_B_CMINDS_Errors_Trails_B "2" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_000966724198_0001 .
#
# nidash:TrailsB_001312253228_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:TrailsBDataStructure,
#         prov:Entity ;
#     nidash:Trails_B_CMINDS_Elapsed_Time_Trails_B "72" ;
#     nidash:Trails_B_CMINDS_Errors_Trails_B "0" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_001312253228_0001 .
#
# nidash:TrailsB_001312445276_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:TrailsBDataStructure,
#         prov:Entity ;
#     nidash:Trails_B_CMINDS_Elapsed_Time_Trails_B "47.3" ;
#     nidash:Trails_B_CMINDS_Errors_Trails_B "0" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_001312445276_0001 .
#
# nidash:Trails_000966724198_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:TrailsDataStructure,
#         prov:Entity ;
#     nidash:Trails_A_CMINDS_Elapsed_Time_Trails_A "24.2" ;
#     nidash:Trails_A_CMINDS_Errors_Trails_A "0" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_000966724198_0001 .
#
# nidash:Trails_001312253228_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:TrailsDataStructure,
#         prov:Entity ;
#     nidash:Trails_A_CMINDS_Elapsed_Time_Trails_A "46.8" ;
#     nidash:Trails_A_CMINDS_Errors_Trails_A "0" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_001312253228_0001 .
#
# nidash:Trails_001312445276_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:TrailsDataStructure,
#         prov:Entity ;
#     nidash:Trails_A_CMINDS_Elapsed_Time_Trails_A "17" ;
#     nidash:Trails_A_CMINDS_Errors_Trails_A "0" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_001312445276_0001 .
#
# nidash:Visit_0002_scanVisit_000966724198 a nidash:Session,
#         prov:Entity ;
#     ncit:StudySiteNumber "0009" ;
#     ncit:VisitNum "0002" ;
#     prov:label "scanVisit" ;
#     prov:wasAttributedTo <http://nidm.nidash.org#000966724198> .
#
# nidash:Visit_0002_scanVisit_001312253228 a nidash:Session,
#         prov:Entity ;
#     ncit:StudySiteNumber "0013" ;
#     ncit:VisitNum "0002" ;
#     prov:label "scanVisit" ;
#     prov:wasAttributedTo <http://nidm.nidash.org#001312253228> .
#
# nidash:Visit_0002_scanVisit_001312445276 a nidash:Session,
#         prov:Entity ;
#     ncit:StudySiteNumber "0013" ;
#     ncit:VisitNum "0002" ;
#     prov:label "scanVisit" ;
#     prov:wasAttributedTo <http://nidm.nidash.org#001312445276> .
#
# nidash:Visual_000966724198_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:VisualDataStructure,
#         prov:Entity ;
#     nidash:Visual_Figural_Learning_Test_CMINDS_Score_1 "5" ;
#     nidash:Visual_Figural_Learning_Test_CMINDS_Score_2 "9" ;
#     nidash:Visual_Figural_Learning_Test_CMINDS_Score_3 "11" ;
#     nidash:Visual_Figural_Learning_Test_CMINDS_Total_Score "25" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_000966724198_0001 .
#
# nidash:Visual_001312253228_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:VisualDataStructure,
#         prov:Entity ;
#     nidash:Visual_Figural_Learning_Test_CMINDS_Score_1 "3" ;
#     nidash:Visual_Figural_Learning_Test_CMINDS_Score_2 "6" ;
#     nidash:Visual_Figural_Learning_Test_CMINDS_Score_3 "8" ;
#     nidash:Visual_Figural_Learning_Test_CMINDS_Total_Score "17" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_001312253228_0001 .
#
# nidash:Visual_001312445276_0001 a nidash:AssessmentAcquisitionObject,
#         nidash:VisualDataStructure,
#         prov:Entity ;
#     nidash:Visual_Figural_Learning_Test_CMINDS_Score_1 "4" ;
#     nidash:Visual_Figural_Learning_Test_CMINDS_Score_2 "10" ;
#     nidash:Visual_Figural_Learning_Test_CMINDS_Score_3 "12" ;
#     nidash:Visual_Figural_Learning_Test_CMINDS_Total_Score "26" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_001312445276_0001 .
#
# nidash:AnatomicalAcquisition_b85dd76b-60b2-11e6-bf77-6c4008b8f03e a prov:Activity ;
#     prov:Used nidash:SIEMENS_TrioTim_3b862754c-60b2-11e6-bed7-6c4008b8f03e ;
#     prov:startedAtTime "130117.171000" .
#
# nidash:AnatomicalAcquisition_c27ad7a3-60b2-11e6-9fcf-6c4008b8f03e a prov:Activity ;
#     prov:Used nidash:SIEMENS_TrioTim_3c27e4cde-60b2-11e6-87cb-6c4008b8f03e ;
#     prov:startedAtTime "150149.899000" .
#
# nidash:AnatomicalAcquisition_cd3fe1de-60b2-11e6-8bd2-6c4008b8f03e a prov:Activity ;
#     prov:Used nidash:SIEMENS_TrioTim_3cd4217a6-60b2-11e6-a83e-6c4008b8f03e ;
#     prov:startedAtTime "183519.393000" .
#
# nidash:InvestigationActivity_b74e6c4a-60b2-11e6-b845-6c4008b8f03e a prov:Activity ;
#     prov:label "Investigation Process Activity" ;
#     prov:wasAssociatedWith nidash:Person_b74ec43a-60b2-11e6-a558-6c4008b8f03e .
#
# nidash:PI a prov:Role ;
#     prov:label "Principle Investigator" .
#
# nidash:Visit_0001_AssessmentAcquisition_000966724198 a nidash:Session,
#         prov:Entity ;
#     ncit:StudySiteNumber "0009" ;
#     ncit:VisitNum "1" ;
#     prov:label "Assessment Acquisition Visit" ;
#     prov:wasAttributedTo <http://nidm.nidash.org#000966724198> .
#
# nidash:Visit_0001_AssessmentAcquisition_001312253228 a nidash:Session,
#         prov:Entity ;
#     ncit:StudySiteNumber "0009" ;
#     ncit:VisitNum "1" ;
#     prov:label "Assessment Acquisition Visit" ;
#     prov:wasAttributedTo <http://nidm.nidash.org#001312253228> .
#
# nidash:Visit_0001_AssessmentAcquisition_001312445276 a nidash:Session,
#         prov:Entity ;
#     ncit:StudySiteNumber "0009" ;
#     ncit:VisitNum "1" ;
#     prov:label "Assessment Acquisition Visit" ;
#     prov:wasAttributedTo <http://nidm.nidash.org#001312445276> .
#
# nidash:Investigation_b74e1847-60b2-11e6-8de5-6c4008b8f03e a nidash:Investigation,
#         dctypes:Dataset,
#         prov:Entity ;
#     dct:description nan ;
#     dct:publisher </storage-grid/FBIRN/fBIRNPhaseIII__0090/Data> ;
#     dct:title "fBIRNPhaseIII__0090"@en ;
#     fbirn:ExperimentID 93441 ;
#     fbirn:StorageType "gridftp"@en ;
#     dcat:accessURL </storage-grid/FBIRN/fBIRNPhaseIII__0090/Data> .
#
# nidash:Person_b74ec43a-60b2-11e6-a558-6c4008b8f03e a prov:Person ;
#     vc:email "sgpotkin@uci.edu" ;
#     prov:hadRole nidash:PI ;
#     prov:wasAssociatedWith nidash:Investigation_b74e1847-60b2-11e6-8de5-6c4008b8f03e ;
#     foaf:familyName "Potkin" ;
#     foaf:givenName "Steven" .
#
# <http://nidm.nidash.org#000966724198> a prov:Person ;
#     ncit:subjectID "000966724198" ;
#     prov:hadRole nidash:Participant .
#
# <http://nidm.nidash.org#001312253228> a prov:Person ;
#     ncit:subjectID "001312253228" ;
#     prov:hadRole nidash:Participant .
#
# <http://nidm.nidash.org#001312445276> a prov:Person ;
#     ncit:subjectID "001312445276" ;
#     prov:hadRole nidash:Participant .
#
# nidash:InvestigationCollection_b74e6a8a-60b2-11e6-914a-6c4008b8f03e a prov:Collection ;
#     prov:hadMember nidash:Investigation_b74e1847-60b2-11e6-8de5-6c4008b8f03e ;
#     prov:label "Investigation Collection" ;
#     prov:wasAttributedTo nidash:Person_b74ec43a-60b2-11e6-a558-6c4008b8f03e ;
#     prov:wasGeneratedBy nidash:InvestigationActivity_b74e6c4a-60b2-11e6-b845-6c4008b8f03e .
#
# nidash:Participant a prov:Role ;
#     prov:label "Participant" .
#
# nidash:SIEMENS_TrioTim_3b862754c-60b2-11e6-bed7-6c4008b8f03e a prov:Agent ;
#     dicom:DeviceSerialNumber "35044" ;
#     dicom:MagneticFieldStrength 3e+00 ;
#     dicom:Manufacturer "SIEMENS" ;
#     dicom:ManufacturerModelName "TrioTim" ;
#     dicom:SoftwareVersion "syngo MR B17" .
#
# nidash:SIEMENS_TrioTim_3c27e4cde-60b2-11e6-87cb-6c4008b8f03e a prov:Agent ;
#     dicom:DeviceSerialNumber "35050" ;
#     dicom:MagneticFieldStrength 3e+00 ;
#     dicom:Manufacturer "SIEMENS" ;
#     dicom:ManufacturerModelName "TrioTim" ;
#     dicom:SoftwareVersion "syngo MR B15" .
#
# nidash:SIEMENS_TrioTim_3cd4217a6-60b2-11e6-a83e-6c4008b8f03e a prov:Agent ;
#     dicom:DeviceSerialNumber "35050" ;
#     dicom:MagneticFieldStrength 3e+00 ;
#     dicom:Manufacturer "SIEMENS" ;
#     dicom:ManufacturerModelName "TrioTim" ;
#     dicom:SoftwareVersion "syngo MR B15" .
#
# nidash:AssessmentCollectionActivity_000966724198_0001 a prov:Activity ;
#     prov:label " Assessment Data Collection Activity" ;
#     prov:wasAssociatedWith <http://nidm.nidash.org#000966724198>,
#         nidash:InvestigationCollection_b74e6a8a-60b2-11e6-914a-6c4008b8f03e,
#         nidash:Visit_0001_AssessmentAcquisition_000966724198 .
#
# nidash:AssessmentCollectionActivity_001312445276_0001 a prov:Activity ;
#     prov:label " Assessment Data Collection Activity" ;
#     prov:wasAssociatedWith <http://nidm.nidash.org#001312445276>,
#         nidash:InvestigationCollection_b74e6a8a-60b2-11e6-914a-6c4008b8f03e,
#         nidash:Visit_0001_AssessmentAcquisition_001312445276 .
#
# nidash:AssessmentCollectionActivity_001312253228_0001 a prov:Activity ;
#     prov:label " Assessment Data Collection Activity" ;
#     prov:wasAssociatedWith <http://nidm.nidash.org#001312253228>,
#         nidash:InvestigationCollection_b74e6a8a-60b2-11e6-914a-6c4008b8f03e,
#         nidash:Visit_0001_AssessmentAcquisition_001312253228 .

# %%
with open("FBIRNPhaseIII_Experiment.ttl",'w') as f:
    f.write(g.serialize(format='turtle'))
with open("FBIRNPhaseIII_DataDictionary.ttl",'w') as f:
    f.write(dd_graph.serialize(format='turtle'))

# %%
from rdflib.tools import rdf2dot
with open("FBIRNPhaseIII_Experiment.dot",'w') as f:
    s = rdf2dot.rdf2dot(g, f)
with open("FBIRNPhaseIII_DataDictionary.dot",'w') as f:
    s = rdf2dot.rdf2dot(dd_graph, f)
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-26-48ddde6ec48e> in <module>()
#       3     s = rdf2dot.rdf2dot(g, f)
#       4 with open("FBIRNPhaseIII_DataDictionary.dot",'w') as f:
# ----> 5     s = rdf2dot.rdf2dot(dd_graph, f)
#
# //anaconda/lib/python2.7/site-packages/rdflib-4.2.dev0-py2.7.egg/rdflib/tools/rdf2dot.pyc in rdf2dot(g, stream, opts)
#     111                 u"<font point-size='10' color='#6666ff'>%s</font></td>" + \
#     112                 u"</tr>%s</table> > ] \n"
# --> 113         stream.write(opstr % (n, NODECOLOR, label(u, g), u, u, u"".join(f)))
#     114
#     115     stream.write("}\n")
#
# UnicodeEncodeError: 'ascii' codec can't encode character u'\u2019' in position 443: ordinal not in range(128)
