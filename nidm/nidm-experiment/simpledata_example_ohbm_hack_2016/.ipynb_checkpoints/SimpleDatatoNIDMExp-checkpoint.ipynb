# %% [markdown]
# #Import Python libraries
# ##rdflib - https://pypi.python.org/pypi/rdflib

# %%
import os
import rdflib as rdf
#import csv for reading csv files
import csv
from rdflib.namespace import XSD
import pandas as pd
import uuid

# %% [markdown]
# #Create new RDF graph

# %%
g = rdf.Graph()

# %% [markdown]
# #Add namespaces
# ## Add a namespace for each one in the object model

# %%
prov = rdf.Namespace("http://www.w3.org/ns/prov#")
ncit = rdf.Namespace("http://ncitt.ncit.nih.gov/")
nidash = rdf.Namespace("http://purl.org/nidash/nidm/")
xnat = rdf.Namespace("https://www.nitrc.org/projects/fcon_1000/")
rdfs = rdf.Namespace("http://www.w3.org/2000/01/rdf-schema#")
dicom = rdf.Namespace("http://neurolex.org/wiki/Category:DICOM_term/")
dct = rdf.Namespace("http://purl.org/dc/terms/")
dctypes = rdf.Namespace("http://purl.org/dc/dcmitype/")
dcat = rdf.Namespace("http://www.w3.org/ns/dcat#")

# %% [markdown]
# #Bind namespaces to graph

# %%
g.bind('prov', prov)
g.bind('ncit', ncit)
g.bind('nidash', nidash)
g.bind('xnat',xnat)
g.bind('dicom',dicom)
g.bind('dct',dct)
g.bind('dctypes', dctypes)
g.bind('dcat', dcat)
list(g.namespaces())
# Out:
# [('xml', rdflib.term.URIRef(u'http://www.w3.org/XML/1998/namespace')),
#  ('ncit', rdflib.term.URIRef(u'http://ncitt.ncit.nih.gov/')),
#  ('rdfs', rdflib.term.URIRef(u'http://www.w3.org/2000/01/rdf-schema#')),
#  ('prov', rdflib.term.URIRef(u'http://www.w3.org/ns/prov#')),
#  ('nidash', rdflib.term.URIRef(u'http://purl.org/nidash/nidm/')),
#  ('dctypes', rdflib.term.URIRef(u'http://purl.org/dc/dcmitype/')),
#  ('rdf', rdflib.term.URIRef(u'http://www.w3.org/1999/02/22-rdf-syntax-ns#')),
#  ('dcat', rdflib.term.URIRef(u'http://www.w3.org/ns/dcat#')),
#  ('xsd', rdflib.term.URIRef(u'http://www.w3.org/2001/XMLSchema#')),
#  ('xnat', rdflib.term.URIRef(u'https://www.nitrc.org/projects/fcon_1000/')),
#  ('dct', rdflib.term.URIRef(u'http://purl.org/dc/terms/')),
#  ('dicom',
#   rdflib.term.URIRef(u'http://neurolex.org/wiki/Category:DICOM_term/'))]

# %% [markdown]
#    #Create function to create element nodes

# %%
def nidm_add_assessment_data(g,row,acq_assessment_uri, assessment_datadict_uri, data_dictionary):
    g.add((nidash[acq_assessment_uri], rdf.RDF.type, nidash["AssessmentAcquisitionObject"]))
    g.add((nidash[acq_assessment_uri], rdf.RDF.type, prov["Entity"]))
    g.add((nidash[acq_assessment_uri], rdf.RDF.type, nidash[assessment_uri]))
    
    #for each variable in the data dictionary, store it's acquired value from this data acquisition
    for key in data_dictionary:
        g.add((nidash[acq_assessment_uri], nidash[data_dictionary[key]], rdf.Literal(row[key])))

# %%
def nidm_create_assessment(g, assessment_uri, assessment_namem, description):
    g.add((nidash[assessment_uri], rdf.RDF.type, nidash["DataStructure"]))
    g.add((nidash[assessment_uri], rdf.RDF.type, prov["Collection"]))
    g.add((nidash[assessment_uri],prov["label"],rdf.Literal(assessment_name)))
    g.add((nidash[assessment_uri],prov["description"],rdf.Literal(description)))

# %%
def nidm_add_codedproperty(g,valueset_id, codedvalue_id, code, label):
    g.add((nidash[codedvalue_id], rdf.RDF.type, nidash["CodedProperty"]))
    g.add((nidash[codedvalue_id], rdf.RDF.type, rdf.RDF.Property))
    g.add((nidash[codedvalue_id],nidash["code"], rdf.Literal(code)))
    g.add((nidash[codedvalue_id], prov["label"], rdf.Literal(label)))
    g.add((nidash[valueset_id], prov["hadMember"], nidash[codedvalue_id]))

# %%
def nidm_create_investigation(g, uid, expid,name):
    g.add((nidash[uid], rdf.RDF.type, dctypes["Dataset"]))
    g.add((nidash[uid], rdf.RDF.type, nidash["Investigation"]))
    g.add((nidash[uid], rdf.RDF.type, prov["Entity"]))
    g.add((nidash[uid], xnat["ProjectID"], rdf.Literal(name, lang='en')))
def nidm_add_investigation_metadata(g, uid, name, description, baseuri):
    g.add((nidash[uid], dct["title"], rdf.Literal(name, lang='en')))
    g.add((nidash[uid], dct["description"], rdf.Literal(description, lang='en')))
    g.add((nidash[uid], dct["publisher"], rdf.URIRef(baseuri)))
    g.add((nidash[uid], dcat["accessURL"], rdf.URIRef(baseuri)))
def nidm_add_session_person(g, uid, subjid, session_activity_uid, session_collection_uid):
    g.add((nidash[uid], rdf.RDF.type, prov["Person"]))
    g.add((nidash[uid], ncit["subjectID"], rdf.Literal(subjid)))
    nidm_add_role(g, nidash["Participant"], "Participant")
    g.add((nidash[uid], prov["hadRole"], nidash["Participant"]))
def nidm_add_role(g, uid, role):
    g.add((uid, rdf.RDF.type, prov["Role"]))
    g.add((uid, prov["label"], rdf.Literal(role)))

# %% [markdown]
# #Read in CSV file and convert to RDF graph

# %%
#load spreadsheet
filename_prefix = "SimpleData"
xls = pd.ExcelFile(filename_prefix+".xlsx")
variables = xls.parse(0)

# %% [markdown]
# #Create simple data dictionary

# %%
assessment_name="SimpleData"
assessment_uri = assessment_name + "_" + str(uuid.uuid1())

#create assessment object for data dictionary
nidm_create_assessment(g,assessment_uri, assessment_name, "XNAT query response document")


#create a simple data dictionary to describe this spreadsheet
#SimpleData has only age, gender, and handedness for interesting assessment measures
#Age
g.add((nidash[assessment_uri+"_Age"], rdf.RDF.type, nidash["DataElement"]))
g.add((nidash[assessment_uri+"_Age"], rdf.RDF.type, rdf.RDF.Property))
g.add((nidash[assessment_uri+"_Age"], rdf.RDF.type, ncit["Age"]))
g.add((nidash[assessment_uri+"_Age"], prov["label"], rdf.Literal("Age")))
g.add((nidash[assessment_uri+"_Age"], nidash["DataType"], rdf.Literal(XSD.integer)))
#make association with assessment
g.add((nidash[assessment_uri],prov["hadMember"], nidash[assessment_uri+"_Age"]))
#Gender, a coded data element
g.add((nidash[assessment_uri+"_Gender"], rdf.RDF.type, nidash["CodedDataElement"]))
g.add((nidash[assessment_uri+"_Gender"], rdf.RDF.type, rdf.RDF.Property))
g.add((nidash[assessment_uri+"_Gender"], rdf.RDF.type, ncit["Gender"]))
g.add((nidash[assessment_uri+"_Gender"], prov["label"], rdf.Literal("Gender")))
g.add((nidash[assessment_uri+"_Gender"], nidash["DataType"], rdf.Literal(XSD.string)))
g.add((nidash[assessment_uri+"_Gender"], nidash["ValueSet"], nidash[assessment_uri+"_Gender_ValueSet"]))
#create gender ValueSet collection
g.add((nidash[assessment_uri+"_Gender_ValueSet"], rdf.RDF.type, prov["Collection"]))
g.add((nidash[assessment_uri+"_Gender_ValueSet"], rdf.RDF.type, nidash["ValueSet"]))
#make association with assessment
g.add((nidash[assessment_uri],prov["hadMember"], nidash[assessment_uri+"_Gender"]))

#create coded-property for Genders
#get unique geneders from data frame
genders = variables['M/F'].unique()
#for each unique gender create a coded property
for gender in genders:
    if gender=='M':
        label='Male'
    else:
        label='Female'
    nidm_add_codedproperty(g,assessment_uri+"_Gender_ValueSet", assessment_uri+"_Gender_"+gender, gender, label)

#Handedness, another valueset
g.add((nidash[assessment_uri+"_Hand"], rdf.RDF.type, nidash["CodedDataElement"]))
g.add((nidash[assessment_uri+"_Hand"], rdf.RDF.type, rdf.RDF.Property))
g.add((nidash[assessment_uri+"_Hand"], rdf.RDF.type, ncit["HandDom"]))
g.add((nidash[assessment_uri+"_Hand"], prov["label"], rdf.Literal("Handedness")))
g.add((nidash[assessment_uri+"_Hand"], nidash["DataType"], rdf.Literal(XSD.string)))
g.add((nidash[assessment_uri+"_Hand"], nidash["ValueSet"], nidash[assessment_uri+"_Hand_ValueSet"]))
#make association with assessment
g.add((nidash[assessment_uri],prov["hadMember"], nidash[assessment_uri+"_Hand"]))
#create coded-property for Handedness
#create hand ValueSet collection
g.add((nidash[assessment_uri+"_Hand_ValueSet"], rdf.RDF.type, prov["Collection"]))
g.add((nidash[assessment_uri+"_Hand_ValueSet"], rdf.RDF.type, nidash["ValueSet"]))
#get unique hands from data frame
hands = variables['Hand'].unique()
#for each unique gender create a coded property
for hand in hands:
      nidm_add_codedproperty(g,assessment_uri+"_Hand_ValueSet", assessment_uri+"_Hand_"+hand, hand, hand)

#save SimpleData data dictionary variable URIs with column header mappings for modeling acquired data
data_dict = {'Age': assessment_uri+"_Age", 'Hand' : assessment_uri+"_Hand", 'M/F': assessment_uri+"_Gender"}

# %% [markdown]
# #Parse/model imaging and acquired assessment data from file

# %%
#create investigation dictionary in case there are multiple projects in spreadsheet
#create investigation collection and activity dictionaries as well
inv_dict = {}
inv_collect_dict = {}
inv_activity_dict = {}
scanner_dict = {}

#create subject dictionary in case there are multiple measurements from a subject
subj_dict = {}

#iterate over the variables in the data file
for index, row in variables.iterrows():

    #if this is a new investigation then add the UUID to dictionary and create entity
    if not inv_dict.has_key(row["Project"]):
        #create investigation UUID
        inv_uri = "Investigation_" + str(uuid.uuid1())
        #keep UUID -> uniqueid mappings for experiments in dictionary in case there are multiple experiments
        inv_dict[row["Project"]] = inv_uri
        #add investigation using HID experiment ID
        nidm_create_investigation(g, inv_uri,inv_dict[row["Project"]],row["Project"])
        #add other metadata
        nidm_add_investigation_metadata(g, inv_uri, row["Project"], "1000 Functional Connectomes Project (FCP)", "http://fcon_1000.projects.nitrc.org/")

        #create an investigation collection / investigation activity
        collect_uri = "InvestigationCollection_" + str(uuid.uuid1())
        inv_collect_dict[row["Project"]] = collect_uri
        #add collection/activities to graph
        g.add((nidash[collect_uri], rdf.RDF.type, prov["Collection"]))
        #add label for debugging/model evaluation
        g.add((nidash[collect_uri],prov["label"], rdf.Literal("Investigation Collection")))
        #associate investigation activity with collection
        g.add((nidash[inv_uri], prov["wasAssociatedWith"], nidash[collect_uri]))
    else:
        inv_uri = inv_dict[row["Project"]]
       
    activity_uri = "AssessmentCollectionActivity_"+str(uuid.uuid1())
    inv_activity_dict[row["Project"]] = activity_uri
    #add collection/activities to graph
    g.add((nidash[activity_uri], rdf.RDF.type, prov["Activity"]))
    #add label for debugging/model evaluation
    g.add((nidash[activity_uri],prov["label"], rdf.Literal("Assessment Data Collection Activity")))
    #associate assessment collection activity with investigation collection
    g.add((nidash[collect_uri],prov["hadMember"],nidash[activity_uri]))
    
    #add elements to RDF graph for variable definitions
    acq_assessment_uri = assessment_name + "_" + str(uuid.uuid1())
    nidm_add_assessment_data(g,row,acq_assessment_uri, assessment_uri, data_dict) 
    
    #associate assessment data with project acquisition activity
    g.add((nidash[acq_assessment_uri], prov["wasGeneratedBy"], nidash[activity_uri]))
    
    #if new subject add subject entity and link to project collection / activity
    if not subj_dict.has_key(row["Subject"]):
        #get subjectID and store in NIDM-Experiment graph
        subj_uid = row["Subject"] + "_" + str(uuid.uuid1())
        subj_dict[row["Subject"]] = subj_uid
        nidm_add_session_person(g,subj_uid, row["Subject"], inv_activity_dict[row["Project"]],inv_collect_dict[row["Project"]])
        #associate person with these session collections/activities
        g.add((nidash[inv_collect_dict[row["Project"]]], prov["wasAttributedTo"], nidash[subj_uid]))
        g.add((nidash[inv_activity_dict[row["Project"]]], prov["wasAssociatedWith"], nidash[subj_uid]))
    else:
        subj_uid = subj_dict[row["Subject"]]
     
    #associate subject information with acquisition activity
    #g.add((nidash[activity_uri],prov["Used"], nidash[subj_dict[row["Subject"]]]))
    
    #associate assessment data with investigation collection
    g.add((nidash[inv_collect_dict[row["Project"]]],prov["hadMember"], nidash[acq_assessment_uri]))
    
    
    #Imaging data
    #create acquisition activity
    activity_uri = "ImagingCollectionActivity_"+str(uuid.uuid1())
    g.add((nidash[activity_uri], rdf.RDF.type, prov["Activity"]))
    #associate with investigation collection
    g.add((nidash[inv_collect_dict[row["Project"]]],prov["hadMember"], nidash[activity_uri]))
    #create scanner agent if not already created, note scanners key'd by Site+FieldStrength
    if not scanner_dict.has_key(row["Acquisition Site"]+'_'+row["Field Strength"]):
        scanner_uri = row["Acquisition Site"]+'_'+row["Field Strength"]+'_'+str(uuid.uuid1())
        scanner_dict[row["Acquisition Site"]+'_'+row["Field Strength"]] = scanner_uri
        g.add((nidash[scanner_uri],rdf.RDF.type, prov["Agent"]))
        #add scanner metadata
        g.add((nidash[scanner_uri],dicom["MagneticFieldStrength"],rdf.Literal(row["Field Strength"])))
        g.add((nidash[scanner_uri],ncit["SiteID"], rdf.Literal(row["Acquisition Site"])))
    #associate scanner agent with acquisition object
    g.add((nidash[activity_uri],prov["Used"], nidash[scanner_dict[row["Acquisition Site"]+'_'+row["Field Strength"]]]))
    #associate subject agent with acquisition object
    g.add((nidash[activity_uri],prov["wasAssociatedWith"], nidash[subj_dict[row["Subject"]]]))
    
    #entity for image
    image_uri = "MRImage_"+str(uuid.uuid1())
    g.add((nidash[image_uri], rdf.RDF.type, prov["Entity"]))
    g.add((nidash[image_uri], prov["atLocation"], rdf.URIRef(row["File Path"])))
    #associate image acquisition entity with acquisition activity
    g.add((nidash[image_uri], prov["wasGeneratedBy"], nidash[activity_uri]))

# %%
print g.serialize(format='turtle')
# Out:
# @prefix dcat: <http://www.w3.org/ns/dcat#> .
# @prefix dct: <http://purl.org/dc/terms/> .
# @prefix dctypes: <http://purl.org/dc/dcmitype/> .
# @prefix dicom: <http://neurolex.org/wiki/Category:DICOM_term/> .
# @prefix ncit: <http://ncitt.ncit.nih.gov/> .
# @prefix nidash: <http://purl.org/nidash/nidm/> .
# @prefix prov: <http://www.w3.org/ns/prov#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xml: <http://www.w3.org/XML/1998/namespace> .
# @prefix xnat: <https://www.nitrc.org/projects/fcon_1000/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# nidash:Investigation_22015d61-5148-11e6-b205-6c4008b8f03e a dctypes:Dataset,
#         nidash:Investigation,
#         prov:Entity ;
#     dct:description "1000 Functional Connectomes Project (FCP)"@en ;
#     dct:publisher <http://fcon_1000.projects.nitrc.org/> ;
#     dct:title "fcon_1000"@en ;
#     dcat:accessURL <http://fcon_1000.projects.nitrc.org/> ;
#     prov:wasAssociatedWith nidash:InvestigationCollection_22017c02-5148-11e6-a427-6c4008b8f03e ;
#     xnat:ProjectID "fcon_1000"@en .
#
# nidash:MRImage_2201d140-5148-11e6-9134-6c4008b8f03e a prov:Entity ;
#     prov:atLocation <http://www.nitrc.org/ir/data/experiments/xnat_E00005/scans/anat_mprage_anonymized/resources/11924/files/scan_mprage_anonymized.nii.gz> ;
#     prov:wasGeneratedBy nidash:ImagingCollectionActivity_2201b1a3-5148-11e6-85f7-6c4008b8f03e .
#
# nidash:MRImage_22021554-5148-11e6-93fc-6c4008b8f03e a prov:Entity ;
#     prov:atLocation <http://www.nitrc.org/ir/data/experiments/xnat_E00007/scans/anat_mprage_anonymized/resources/11930/files/scan_mprage_anonymized.nii.gz> ;
#     prov:wasGeneratedBy nidash:ImagingCollectionActivity_22020b54-5148-11e6-aace-6c4008b8f03e .
#
# nidash:MRImage_220250f0-5148-11e6-a4f2-6c4008b8f03e a prov:Entity ;
#     prov:atLocation <http://www.nitrc.org/ir/data/experiments/xnat_E00011/scans/anat_mprage_anonymized/resources/11942/files/scan_mprage_anonymized.nii.gz> ;
#     prov:wasGeneratedBy nidash:ImagingCollectionActivity_220246f0-5148-11e6-bfcd-6c4008b8f03e .
#
# nidash:MRImage_22028c4f-5148-11e6-8114-6c4008b8f03e a prov:Entity ;
#     prov:atLocation <http://www.nitrc.org/ir/data/experiments/xnat_E00013/scans/anat_mprage_anonymized/resources/11948/files/scan_mprage_anonymized.nii.gz> ;
#     prov:wasGeneratedBy nidash:ImagingCollectionActivity_22028263-5148-11e6-8f43-6c4008b8f03e .
#
# nidash:MRImage_2202c80a-5148-11e6-9958-6c4008b8f03e a prov:Entity ;
#     prov:atLocation <http://www.nitrc.org/ir/data/experiments/xnat_E00016/scans/anat_mprage_anonymized/resources/11956/files/scan_mprage_anonymized.nii.gz> ;
#     prov:wasGeneratedBy nidash:ImagingCollectionActivity_2202bde3-5148-11e6-882e-6c4008b8f03e .
#
# nidash:MRImage_2203093d-5148-11e6-9a61-6c4008b8f03e a prov:Entity ;
#     prov:atLocation <http://www.nitrc.org/ir/data/experiments/xnat_E00022/scans/anat_mprage_anonymized/resources/11973/files/scan_mprage_anonymized.nii.gz> ;
#     prov:wasGeneratedBy nidash:ImagingCollectionActivity_2202fd2b-5148-11e6-923e-6c4008b8f03e .
#
# nidash:MRImage_22034699-5148-11e6-a60f-6c4008b8f03e a prov:Entity ;
#     prov:atLocation <http://www.nitrc.org/ir/data/experiments/xnat_E00023/scans/anat_mprage_anonymized/resources/11976/files/scan_mprage_anonymized.nii.gz> ;
#     prov:wasGeneratedBy nidash:ImagingCollectionActivity_22033c7a-5148-11e6-a233-6c4008b8f03e .
#
# nidash:MRImage_22038285-5148-11e6-bc4f-6c4008b8f03e a prov:Entity ;
#     prov:atLocation <http://www.nitrc.org/ir/data/experiments/xnat_E00024/scans/anat_mprage_anonymized/resources/11979/files/scan_mprage_anonymized.nii.gz> ;
#     prov:wasGeneratedBy nidash:ImagingCollectionActivity_2203780f-5148-11e6-a042-6c4008b8f03e .
#
# nidash:MRImage_2203bef3-5148-11e6-94e7-6c4008b8f03e a prov:Entity ;
#     prov:atLocation <http://www.nitrc.org/ir/data/experiments/xnat_E00025/scans/anat_mprage_anonymized/resources/11982/files/scan_mprage_anonymized.nii.gz> ;
#     prov:wasGeneratedBy nidash:ImagingCollectionActivity_2203b542-5148-11e6-9626-6c4008b8f03e .
#
# nidash:MRImage_22040666-5148-11e6-a9dc-6c4008b8f03e a prov:Entity ;
#     prov:atLocation <http://www.nitrc.org/ir/data/experiments/xnat_E00937/scans/anat_mprage_anonymized/resources/14860/files/scan_mprage_anonymized.nii.gz> ;
#     prov:wasGeneratedBy nidash:ImagingCollectionActivity_2203f126-5148-11e6-bef9-6c4008b8f03e .
#
# nidash:MRImage_2204395e-5148-11e6-9035-6c4008b8f03e a prov:Entity ;
#     prov:atLocation <http://www.nitrc.org/ir/data/experiments/xnat_E00939/scans/anat_mprage_anonymized/resources/14866/files/scan_mprage_anonymized.nii.gz> ;
#     prov:wasGeneratedBy nidash:ImagingCollectionActivity_22043117-5148-11e6-817d-6c4008b8f03e .
#
# nidash:MRImage_22046be3-5148-11e6-84e4-6c4008b8f03e a prov:Entity ;
#     prov:atLocation <http://www.nitrc.org/ir/data/experiments/xnat_E00941/scans/anat_mprage_anonymized/resources/14872/files/scan_mprage_anonymized.nii.gz> ;
#     prov:wasGeneratedBy nidash:ImagingCollectionActivity_22046354-5148-11e6-a199-6c4008b8f03e .
#
# nidash:MRImage_22049c78-5148-11e6-80d8-6c4008b8f03e a prov:Entity ;
#     prov:atLocation <http://www.nitrc.org/ir/data/experiments/xnat_E00949/scans/anat_mprage_anonymized/resources/14896/files/scan_mprage_anonymized.nii.gz> ;
#     prov:wasGeneratedBy nidash:ImagingCollectionActivity_22049428-5148-11e6-83f0-6c4008b8f03e .
#
# nidash:MRImage_2204d014-5148-11e6-a50d-6c4008b8f03e a prov:Entity ;
#     prov:atLocation <http://www.nitrc.org/ir/data/experiments/xnat_E00958/scans/anat_mprage_anonymized/resources/14923/files/scan_mprage_anonymized.nii.gz> ;
#     prov:wasGeneratedBy nidash:ImagingCollectionActivity_2204c7fd-5148-11e6-b3a6-6c4008b8f03e .
#
# nidash:MRImage_22050259-5148-11e6-87c1-6c4008b8f03e a prov:Entity ;
#     prov:atLocation <http://www.nitrc.org/ir/data/experiments/xnat_E00974/scans/anat_mprage_anonymized/resources/6978/files/scan_mprage_anonymized.nii.gz> ;
#     prov:wasGeneratedBy nidash:ImagingCollectionActivity_2204fa26-5148-11e6-a626-6c4008b8f03e .
#
# nidash:MRImage_220532c0-5148-11e6-a3a6-6c4008b8f03e a prov:Entity ;
#     prov:atLocation <http://www.nitrc.org/ir/data/experiments/xnat_E00975/scans/anat_mprage_anonymized/resources/6981/files/scan_mprage_anonymized.nii.gz> ;
#     prov:wasGeneratedBy nidash:ImagingCollectionActivity_22052aab-5148-11e6-a28b-6c4008b8f03e .
#
# nidash:MRImage_220564c0-5148-11e6-ac85-6c4008b8f03e a prov:Entity ;
#     prov:atLocation <http://www.nitrc.org/ir/data/experiments/xnat_E00976/scans/anat_mprage_anonymized/resources/6984/files/scan_mprage_anonymized.nii.gz> ;
#     prov:wasGeneratedBy nidash:ImagingCollectionActivity_22055c97-5148-11e6-a3da-6c4008b8f03e .
#
# nidash:MRImage_2205959e-5148-11e6-811c-6c4008b8f03e a prov:Entity ;
#     prov:atLocation <http://www.nitrc.org/ir/data/experiments/xnat_E00981/scans/anat_mprage_anonymized/resources/6999/files/scan_mprage_anonymized.nii.gz> ;
#     prov:wasGeneratedBy nidash:ImagingCollectionActivity_22058d73-5148-11e6-a555-6c4008b8f03e .
#
# nidash:MRImage_2205c6eb-5148-11e6-bfe5-6c4008b8f03e a prov:Entity ;
#     prov:atLocation <http://www.nitrc.org/ir/data/experiments/xnat_E00983/scans/anat_mprage_anonymized/resources/7005/files/scan_mprage_anonymized.nii.gz> ;
#     prov:wasGeneratedBy nidash:ImagingCollectionActivity_2205be8c-5148-11e6-af9a-6c4008b8f03e .
#
# nidash:MRImage_2205f7e6-5148-11e6-b9b9-6c4008b8f03e a prov:Entity ;
#     prov:atLocation <http://www.nitrc.org/ir/data/experiments/xnat_E00984/scans/anat_mprage_anonymized/resources/7008/files/scan_mprage_anonymized.nii.gz> ;
#     prov:wasGeneratedBy nidash:ImagingCollectionActivity_2205efcf-5148-11e6-b907-6c4008b8f03e .
#
# nidash:MRImage_22062805-5148-11e6-af88-6c4008b8f03e a prov:Entity ;
#         nidash:NewYork_sub61241_22054dbd-5148-11e6-82b2-6c4008b8f03e,
#         nidash:NewYork_sub66941_22057fa8-5148-11e6-90ec-6c4008b8f03e,
#         nidash:NewYork_sub70752_2205b0e1-5148-11e6-9832-6c4008b8f03e,
#         nidash:NewYork_sub73490_2205e207-5148-11e6-990e-6c4008b8f03e,
#         nidash:NewYork_sub84978_22061207-5148-11e6-8368-6c4008b8f03e,
#         nidash:NewYork_sub88286_220641f5-5148-11e6-bc48-6c4008b8f03e,
#         nidash:NewYork_sub93975_2206736b-5148-11e6-b222-6c4008b8f03e,
#         nidash:NewYork_sub96705_2206a285-5148-11e6-92a9-6c4008b8f03e .
#
# nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Age a ncit:Age,
#         nidash:DataElement,
#         rdf:Property ;
#     nidash:DataType "http://www.w3.org/2001/XMLSchema#integer" ;
#     prov:label "Age" .
#
# nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Gender a ncit:Gender,
#         nidash:CodedDataElement,
#         rdf:Property ;
#     nidash:DataType "http://www.w3.org/2001/XMLSchema#string" ;
#     nidash:ValueSet nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Gender_ValueSet ;
#     prov:label "Gender" .
#
# nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Gender_F a nidash:CodedProperty,
#         rdf:Property ;
#     nidash:code "F" ;
#     prov:label "Female" .
#
# nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Gender_M a nidash:CodedProperty,
#         rdf:Property ;
#     nidash:code "M" ;
#     prov:label "Male" .
#
# nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Gender_ValueSet a nidash:ValueSet,
#         prov:Collection ;
#     prov:hadMember nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Gender_F,
#         nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Gender_M .
#
# nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Hand a ncit:HandDom,
#         nidash:CodedDataElement,
#         rdf:Property ;
#     nidash:DataType "http://www.w3.org/2001/XMLSchema#string" ;
#     nidash:ValueSet nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Hand_ValueSet ;
#     prov:label "Handedness" .
#
# nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Hand_ValueSet a nidash:ValueSet,
#         prov:Collection ;
#     prov:hadMember nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Hand_left,
#         nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Hand_right,
#         nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Hand_unknown .
#
# nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Hand_left a nidash:CodedProperty,
#         rdf:Property ;
#     nidash:code "left" ;
#     prov:label "left" .
#
# nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Hand_right a nidash:CodedProperty,
#         rdf:Property ;
#     nidash:code "right" ;
#     prov:label "right" .
#
# nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Hand_unknown a nidash:CodedProperty,
#         rdf:Property ;
#     nidash:code "unknown" ;
#     prov:label "unknown" .
#
# nidash:SimpleData_22018fe3-5148-11e6-9438-6c4008b8f03e a nidash:AssessmentAcquisitionObject,
#         nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e,
#         prov:Entity ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Age 13 ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Gender "M" ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Hand "right" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_220187a6-5148-11e6-936f-6c4008b8f03e .
#
# nidash:SimpleData_2201eb2e-5148-11e6-9d66-6c4008b8f03e a nidash:AssessmentAcquisitionObject,
#         nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e,
#         prov:Entity ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Age 15 ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Gender "M" ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Hand "right" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_2201e200-5148-11e6-bef0-6c4008b8f03e .
#
# nidash:SimpleData_220226fa-5148-11e6-b1a6-6c4008b8f03e a nidash:AssessmentAcquisitionObject,
#         nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e,
#         prov:Entity ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Age 14 ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Gender "M" ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Hand "right" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_2202201c-5148-11e6-aeb4-6c4008b8f03e .
#
# nidash:SimpleData_22026251-5148-11e6-a4d2-6c4008b8f03e a nidash:AssessmentAcquisitionObject,
#         nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e,
#         prov:Entity ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Age 13 ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Gender "F" ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Hand "right" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_22025b7a-5148-11e6-8c2a-6c4008b8f03e .
#
# nidash:SimpleData_22029dcf-5148-11e6-83c6-6c4008b8f03e a nidash:AssessmentAcquisitionObject,
#         nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e,
#         prov:Entity ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Age 13 ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Gender "M" ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Hand "left" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_22029702-5148-11e6-b321-6c4008b8f03e .
#
# nidash:SimpleData_2202d93a-5148-11e6-b84a-6c4008b8f03e a nidash:AssessmentAcquisitionObject,
#         nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e,
#         prov:Entity ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Age 14 ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Gender "M" ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Hand "right" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_2202d26e-5148-11e6-9232-6c4008b8f03e .
#
# nidash:SimpleData_22031c4a-5148-11e6-b6b6-6c4008b8f03e a nidash:AssessmentAcquisitionObject,
#         nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e,
#         prov:Entity ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Age 15 ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Gender "M" ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Hand "right" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_22031559-5148-11e6-b360-6c4008b8f03e .
#
# nidash:SimpleData_220357e8-5148-11e6-982e-6c4008b8f03e a nidash:AssessmentAcquisitionObject,
#         nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e,
#         prov:Entity ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Age 14 ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Gender "M" ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Hand "right" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_22035107-5148-11e6-a839-6c4008b8f03e .
#
# nidash:SimpleData_220393a1-5148-11e6-8cad-6c4008b8f03e a nidash:AssessmentAcquisitionObject,
#         nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e,
#         prov:Entity ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Age 15 ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Gender "M" ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Hand "right" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_22038d42-5148-11e6-8e9e-6c4008b8f03e .
#
# nidash:SimpleData_2203cf85-5148-11e6-949d-6c4008b8f03e a nidash:AssessmentAcquisitionObject,
#         nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e,
#         prov:Entity ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Age 11 ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Gender "M" ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Hand "unknown" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_2203c8f3-5148-11e6-82a2-6c4008b8f03e .
#
# nidash:SimpleData_220415a3-5148-11e6-99ba-6c4008b8f03e a nidash:AssessmentAcquisitionObject,
#         nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e,
#         prov:Entity ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Age 15 ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Gender "F" ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Hand "unknown" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_22040fd1-5148-11e6-9133-6c4008b8f03e .
#
# nidash:SimpleData_220447fa-5148-11e6-a022-6c4008b8f03e a nidash:AssessmentAcquisitionObject,
#         nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e,
#         prov:Entity ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Age 10 ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Gender "M" ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Hand "unknown" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_22044233-5148-11e6-94e2-6c4008b8f03e .
#
# nidash:SimpleData_22047a57-5148-11e6-86a5-6c4008b8f03e a nidash:AssessmentAcquisitionObject,
#         nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e,
#         prov:Entity ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Age 12 ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Gender "M" ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Hand "unknown" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_22047497-5148-11e6-902f-6c4008b8f03e .
#
# nidash:SimpleData_2204aaf5-5148-11e6-b518-6c4008b8f03e a nidash:AssessmentAcquisitionObject,
#         nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e,
#         prov:Entity ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Age 15 ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Gender "F" ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Hand "unknown" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_2204a53a-5148-11e6-b83e-6c4008b8f03e .
#
# nidash:SimpleData_2204dfd1-5148-11e6-a496-6c4008b8f03e a nidash:AssessmentAcquisitionObject,
#         nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e,
#         prov:Entity ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Age 14 ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Gender "M" ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Hand "unknown" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_2204d9eb-5148-11e6-9f41-6c4008b8f03e .
#
# nidash:SimpleData_220510d7-5148-11e6-8706-6c4008b8f03e a nidash:AssessmentAcquisitionObject,
#         nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e,
#         prov:Entity ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Age 13 ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Gender "M" ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Hand "unknown" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_22050b40-5148-11e6-ad73-6c4008b8f03e .
#
# nidash:SimpleData_2205413d-5148-11e6-b587-6c4008b8f03e a nidash:AssessmentAcquisitionObject,
#         nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e,
#         prov:Entity ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Age 15 ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Gender "F" ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Hand "unknown" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_22053b9e-5148-11e6-879d-6c4008b8f03e .
#
# nidash:SimpleData_220572ee-5148-11e6-b333-6c4008b8f03e a nidash:AssessmentAcquisitionObject,
#         nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e,
#         prov:Entity ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Age 14 ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Gender "M" ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Hand "unknown" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_22056d63-5148-11e6-9b29-6c4008b8f03e .
#
# nidash:SimpleData_2205a438-5148-11e6-a42e-6c4008b8f03e a nidash:AssessmentAcquisitionObject,
#         nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e,
#         prov:Entity ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Age 15 ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Gender "F" ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Hand "unknown" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_22059e99-5148-11e6-babc-6c4008b8f03e .
#
# nidash:SimpleData_2205d570-5148-11e6-b642-6c4008b8f03e a nidash:AssessmentAcquisitionObject,
#         nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e,
#         prov:Entity ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Age 12 ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Gender "M" ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Hand "unknown" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_2205cfdc-5148-11e6-b83c-6c4008b8f03e .
#
# nidash:SimpleData_2206060a-5148-11e6-9d46-6c4008b8f03e a nidash:AssessmentAcquisitionObject,
#         nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e,
#         prov:Entity ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Age 12 ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Gender "F" ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Hand "unknown" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_22060087-5148-11e6-90e8-6c4008b8f03e .
#
# nidash:SimpleData_220635e3-5148-11e6-8c81-6c4008b8f03e a nidash:AssessmentAcquisitionObject,
#         nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e,
#         prov:Entity ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Age 15 ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Gender "F" ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Hand "unknown" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_22063075-5148-11e6-90cf-6c4008b8f03e .
#
# nidash:SimpleData_22066775-5148-11e6-8d63-6c4008b8f03e a nidash:AssessmentAcquisitionObject,
#         nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e,
#         prov:Entity ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Age 12 ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Gender "F" ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Hand "unknown" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_22066207-5148-11e6-a7d3-6c4008b8f03e .
#
# nidash:SimpleData_22069657-5148-11e6-a7bf-6c4008b8f03e a nidash:AssessmentAcquisitionObject,
#         nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e,
#         prov:Entity ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Age 13 ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Gender "M" ;
#     nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Hand "unknown" ;
#     prov:wasGeneratedBy nidash:AssessmentCollectionActivity_220690f3-5148-11e6-83bd-6c4008b8f03e .
#
# nidash:AssessmentCollectionActivity_220187a6-5148-11e6-936f-6c4008b8f03e a prov:Activity ;
#     prov:label "Assessment Data Collection Activity" ;
#     prov:wasAssociatedWith nidash:AnnArbor_sub16960_22019d17-5148-11e6-88ba-6c4008b8f03e .
#
# nidash:AssessmentCollectionActivity_2201e200-5148-11e6-bef0-6c4008b8f03e a prov:Activity ;
#     prov:label "Assessment Data Collection Activity" ;
#     prov:wasAssociatedWith nidash:AnnArbor_sub20317_2201fa7d-5148-11e6-bc9a-6c4008b8f03e .
#
# nidash:AssessmentCollectionActivity_2202201c-5148-11e6-aeb4-6c4008b8f03e a prov:Activity ;
#     prov:label "Assessment Data Collection Activity" ;
#     prov:wasAssociatedWith nidash:AnnArbor_sub38614_22023623-5148-11e6-93c6-6c4008b8f03e .
#
# nidash:AssessmentCollectionActivity_22025b7a-5148-11e6-8c2a-6c4008b8f03e a prov:Activity ;
#     prov:label "Assessment Data Collection Activity" ;
#     prov:wasAssociatedWith nidash:AnnArbor_sub46727_22027197-5148-11e6-ae9e-6c4008b8f03e .
#
# nidash:AssessmentCollectionActivity_22029702-5148-11e6-b321-6c4008b8f03e a prov:Activity ;
#     prov:label "Assessment Data Collection Activity" ;
#     prov:wasAssociatedWith nidash:AnnArbor_sub49687_2202ad02-5148-11e6-b1f7-6c4008b8f03e .
#
# nidash:AssessmentCollectionActivity_2202d26e-5148-11e6-9232-6c4008b8f03e a prov:Activity ;
#     prov:label "Assessment Data Collection Activity" ;
#     prov:wasAssociatedWith nidash:AnnArbor_sub82334_2202e878-5148-11e6-a4e9-6c4008b8f03e .
#
# nidash:AssessmentCollectionActivity_22031559-5148-11e6-b360-6c4008b8f03e a prov:Activity ;
#     prov:label "Assessment Data Collection Activity" ;
#     prov:wasAssociatedWith nidash:AnnArbor_sub86367_22032b75-5148-11e6-a108-6c4008b8f03e .
#
# nidash:AssessmentCollectionActivity_22035107-5148-11e6-a839-6c4008b8f03e a prov:Activity ;
#     prov:label "Assessment Data Collection Activity" ;
#     prov:wasAssociatedWith nidash:AnnArbor_sub87745_22036723-5148-11e6-9888-6c4008b8f03e .
#
# nidash:AssessmentCollectionActivity_22038d42-5148-11e6-8e9e-6c4008b8f03e a prov:Activity ;
#     prov:label "Assessment Data Collection Activity" ;
#     prov:wasAssociatedWith nidash:AnnArbor_sub96621_2203a43d-5148-11e6-a4ed-6c4008b8f03e .
#
# nidash:AssessmentCollectionActivity_2203c8f3-5148-11e6-82a2-6c4008b8f03e a prov:Activity ;
#     prov:label "Assessment Data Collection Activity" ;
#     prov:wasAssociatedWith nidash:NewYork_sub20732_2203def3-5148-11e6-bc56-6c4008b8f03e .
#
# nidash:AssessmentCollectionActivity_22040fd1-5148-11e6-9133-6c4008b8f03e a prov:Activity ;
#     prov:label "Assessment Data Collection Activity" ;
#     prov:wasAssociatedWith nidash:NewYork_sub26267_22042359-5148-11e6-b8a5-6c4008b8f03e .
# nidash:ImagingCollectionActivity_2205be8c-5148-11e6-af9a-6c4008b8f03e a prov:Activity ;
#     prov:Used nidash:NewYork_3T_2203fa7d-5148-11e6-89de-6c4008b8f03e ;
#     prov:wasAssociatedWith nidash:NewYork_sub70752_2205b0e1-5148-11e6-9832-6c4008b8f03e .
#
# nidash:ImagingCollectionActivity_2205efcf-5148-11e6-b907-6c4008b8f03e a prov:Activity ;
#     prov:Used nidash:NewYork_3T_2203fa7d-5148-11e6-89de-6c4008b8f03e ;
#     prov:wasAssociatedWith nidash:NewYork_sub73490_2205e207-5148-11e6-990e-6c4008b8f03e .
#
# nidash:ImagingCollectionActivity_22061fb5-5148-11e6-9a76-6c4008b8f03e a prov:Activity ;
#     prov:Used nidash:NewYork_3T_2203fa7d-5148-11e6-89de-6c4008b8f03e ;
#     prov:wasAssociatedWith nidash:NewYork_sub84978_22061207-5148-11e6-8368-6c4008b8f03e .
#
# nidash:ImagingCollectionActivity_22064fb5-5148-11e6-80dc-6c4008b8f03e a prov:Activity ;
#     prov:Used nidash:NewYork_3T_2203fa7d-5148-11e6-89de-6c4008b8f03e ;
#     prov:wasAssociatedWith nidash:NewYork_sub88286_220641f5-5148-11e6-bc48-6c4008b8f03e .
#
# nidash:ImagingCollectionActivity_220680a8-5148-11e6-b5a2-6c4008b8f03e a prov:Activity ;
#     prov:Used nidash:NewYork_3T_2203fa7d-5148-11e6-89de-6c4008b8f03e ;
#     prov:wasAssociatedWith nidash:NewYork_sub93975_2206736b-5148-11e6-b222-6c4008b8f03e .
#
# nidash:ImagingCollectionActivity_2206aff5-5148-11e6-bfec-6c4008b8f03e a prov:Activity ;
#     prov:Used nidash:NewYork_3T_2203fa7d-5148-11e6-89de-6c4008b8f03e ;
#     prov:wasAssociatedWith nidash:NewYork_sub96705_2206a285-5148-11e6-92a9-6c4008b8f03e .
#
# nidash:AnnArbor_sub16960_22019d17-5148-11e6-88ba-6c4008b8f03e a prov:Person ;
#     ncit:subjectID "AnnArbor_sub16960" ;
#     prov:hadRole nidash:Participant .
#
# nidash:AnnArbor_sub20317_2201fa7d-5148-11e6-bc9a-6c4008b8f03e a prov:Person ;
#     ncit:subjectID "AnnArbor_sub20317" ;
#     prov:hadRole nidash:Participant .
#
# nidash:AnnArbor_sub38614_22023623-5148-11e6-93c6-6c4008b8f03e a prov:Person ;
#     ncit:subjectID "AnnArbor_sub38614" ;
#     prov:hadRole nidash:Participant .
#
# nidash:AnnArbor_sub46727_22027197-5148-11e6-ae9e-6c4008b8f03e a prov:Person ;
#     ncit:subjectID "AnnArbor_sub46727" ;
#     prov:hadRole nidash:Participant .
#
# nidash:AnnArbor_sub49687_2202ad02-5148-11e6-b1f7-6c4008b8f03e a prov:Person ;
#     ncit:subjectID "AnnArbor_sub49687" ;
#     prov:hadRole nidash:Participant .
#
# nidash:AnnArbor_sub82334_2202e878-5148-11e6-a4e9-6c4008b8f03e a prov:Person ;
#     ncit:subjectID "AnnArbor_sub82334" ;
#     prov:hadRole nidash:Participant .
#
# nidash:AnnArbor_sub86367_22032b75-5148-11e6-a108-6c4008b8f03e a prov:Person ;
#     ncit:subjectID "AnnArbor_sub86367" ;
#     prov:hadRole nidash:Participant .
#
# nidash:AnnArbor_sub87745_22036723-5148-11e6-9888-6c4008b8f03e a prov:Person ;
#     ncit:subjectID "AnnArbor_sub87745" ;
#     prov:hadRole nidash:Participant .
#
# nidash:AnnArbor_sub96621_2203a43d-5148-11e6-a4ed-6c4008b8f03e a prov:Person ;
#     ncit:subjectID "AnnArbor_sub96621" ;
#     prov:hadRole nidash:Participant .
#
# nidash:NewYork_sub20732_2203def3-5148-11e6-bc56-6c4008b8f03e a prov:Person ;
#     ncit:subjectID "NewYork_sub20732" ;
#     prov:hadRole nidash:Participant .
#
# nidash:NewYork_sub26267_22042359-5148-11e6-b8a5-6c4008b8f03e a prov:Person ;
#     ncit:subjectID "NewYork_sub26267" ;
#     prov:hadRole nidash:Participant .
#
# nidash:NewYork_sub28795_2204553a-5148-11e6-9736-6c4008b8f03e a prov:Person ;
#     ncit:subjectID "NewYork_sub28795" ;
#     prov:hadRole nidash:Participant .
#
# nidash:NewYork_sub31671_2204869c-5148-11e6-8a2a-6c4008b8f03e a prov:Person ;
#     ncit:subjectID "NewYork_sub31671" ;
#     prov:hadRole nidash:Participant .
#
# nidash:NewYork_sub44979_2204ba33-5148-11e6-b2b9-6c4008b8f03e a prov:Person ;
#     ncit:subjectID "NewYork_sub44979" ;
#     prov:hadRole nidash:Participant .
#
# nidash:NewYork_sub59589_2204ec3d-5148-11e6-8bd8-6c4008b8f03e a prov:Person ;
#     ncit:subjectID "NewYork_sub59589" ;
#     prov:hadRole nidash:Participant .
#
# nidash:NewYork_sub61001_22051d1c-5148-11e6-90bb-6c4008b8f03e a prov:Person ;
#     ncit:subjectID "NewYork_sub61001" ;
#     prov:hadRole nidash:Participant .
#
# nidash:NewYork_sub61241_22054dbd-5148-11e6-82b2-6c4008b8f03e a prov:Person ;
#     ncit:subjectID "NewYork_sub61241" ;
#     prov:hadRole nidash:Participant .
#
# nidash:NewYork_sub66941_22057fa8-5148-11e6-90ec-6c4008b8f03e a prov:Person ;
#     ncit:subjectID "NewYork_sub66941" ;
#     prov:hadRole nidash:Participant .
#
# nidash:NewYork_sub70752_2205b0e1-5148-11e6-9832-6c4008b8f03e a prov:Person ;
#     ncit:subjectID "NewYork_sub70752" ;
#     prov:hadRole nidash:Participant .
#
# nidash:NewYork_sub73490_2205e207-5148-11e6-990e-6c4008b8f03e a prov:Person ;
#     ncit:subjectID "NewYork_sub73490" ;
#     prov:hadRole nidash:Participant .
#
# nidash:NewYork_sub84978_22061207-5148-11e6-8368-6c4008b8f03e a prov:Person ;
#     ncit:subjectID "NewYork_sub84978" ;
#     prov:hadRole nidash:Participant .
#
# nidash:NewYork_sub88286_220641f5-5148-11e6-bc48-6c4008b8f03e a prov:Person ;
#     ncit:subjectID "NewYork_sub88286" ;
#     prov:hadRole nidash:Participant .
#
# nidash:NewYork_sub93975_2206736b-5148-11e6-b222-6c4008b8f03e a prov:Person ;
#     ncit:subjectID "NewYork_sub93975" ;
#     prov:hadRole nidash:Participant .
#
# nidash:NewYork_sub96705_2206a285-5148-11e6-92a9-6c4008b8f03e a prov:Person ;
#     ncit:subjectID "NewYork_sub96705" ;
#     prov:hadRole nidash:Participant .
#
# nidash:AnnArbor_3T_2201b878-5148-11e6-adf6-6c4008b8f03e a prov:Agent ;
#     ncit:SiteID "AnnArbor" ;
#     dicom:MagneticFieldStrength "3T" .
#
# nidash:NewYork_3T_2203fa7d-5148-11e6-89de-6c4008b8f03e a prov:Agent ;
#     ncit:SiteID "NewYork" ;
#     dicom:MagneticFieldStrength "3T" .
#
# nidash:Participant a prov:Role ;
#     prov:label "Participant" .
#
# nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e a nidash:DataStructure,
#         prov:Collection ;
#     prov:description "XNAT query response document" ;
#     prov:hadMember nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Age,
#         nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Gender,
#         nidash:SimpleData_21ef6851-5148-11e6-83b4-6c4008b8f03e_Hand ;
#     prov:label "SimpleData" .

# %% [markdown]
# #Save RDF Turtle file to disk

# %%
with open(filename_prefix+".ttl",'w') as f:
    f.write(g.serialize(format='turtle'))

# %% [markdown]
# #Create RDF graph from DOT file

# %%
from rdflib.tools import rdf2dot
with open(filename_prefix+".dot",'w') as f:
    s = rdf2dot.rdf2dot(g, f)

# %%
import pydot
g = pydot.graph_from_dot_file(filename_prefix+".dot")
g.write_png(filename_prefix+'.png')
# Out:
# 1.0.29

# %% [markdown]
# #Sample Queries

# %%
import rdflib as rdf 
#reload data
g=rdf.Graph().parse("SimpleData.ttl",format='turtle')

# %%
#get image URLs for subjects Age > 12
qres = g.query (
    """select ?age ?img_loc
    where {
        # ?agedd a ncit:Age .
        # ?entity ?agedd ?age ;
            prov:wasGeneratedBy/prov:wasAssociatedWith ?subject .
        # ?img_entity prov:wasGeneratedBy/prov:wasAssociatedWith ?subject ;
            prov:atLocation ?img_loc .
        filter (?age > 12)     
    }
    order by ?age
    """)
print("Age \t Image URL\n")
for row in qres:
    print ("%s \t %s" % row)
# Out:
# Age 	 Image URL
#
# 13 	 http://www.nitrc.org/ir/data/experiments/xnat_E01002/scans/anat_mprage_anonymized/resources/7062/files/scan_mprage_anonymized.nii.gz
# 13 	 http://www.nitrc.org/ir/data/experiments/xnat_E00016/scans/anat_mprage_anonymized/resources/11956/files/scan_mprage_anonymized.nii.gz
# 13 	 http://www.nitrc.org/ir/data/experiments/xnat_E00013/scans/anat_mprage_anonymized/resources/11948/files/scan_mprage_anonymized.nii.gz
# 13 	 http://www.nitrc.org/ir/data/experiments/xnat_E00975/scans/anat_mprage_anonymized/resources/6981/files/scan_mprage_anonymized.nii.gz
# 13 	 http://www.nitrc.org/ir/data/experiments/xnat_E00005/scans/anat_mprage_anonymized/resources/11924/files/scan_mprage_anonymized.nii.gz
# 14 	 http://www.nitrc.org/ir/data/experiments/xnat_E00011/scans/anat_mprage_anonymized/resources/11942/files/scan_mprage_anonymized.nii.gz
# 14 	 http://www.nitrc.org/ir/data/experiments/xnat_E00981/scans/anat_mprage_anonymized/resources/6999/files/scan_mprage_anonymized.nii.gz
# 14 	 http://www.nitrc.org/ir/data/experiments/xnat_E00024/scans/anat_mprage_anonymized/resources/11979/files/scan_mprage_anonymized.nii.gz
# 14 	 http://www.nitrc.org/ir/data/experiments/xnat_E00022/scans/anat_mprage_anonymized/resources/11973/files/scan_mprage_anonymized.nii.gz
# 14 	 http://www.nitrc.org/ir/data/experiments/xnat_E00974/scans/anat_mprage_anonymized/resources/6978/files/scan_mprage_anonymized.nii.gz
# 15 	 http://www.nitrc.org/ir/data/experiments/xnat_E00023/scans/anat_mprage_anonymized/resources/11976/files/scan_mprage_anonymized.nii.gz
# 15 	 http://www.nitrc.org/ir/data/experiments/xnat_E00007/scans/anat_mprage_anonymized/resources/11930/files/scan_mprage_anonymized.nii.gz
# 15 	 http://www.nitrc.org/ir/data/experiments/xnat_E00976/scans/anat_mprage_anonymized/resources/6984/files/scan_mprage_anonymized.nii.gz
# 15 	 http://www.nitrc.org/ir/data/experiments/xnat_E00994/scans/anat_mprage_anonymized/resources/7038/files/scan_mprage_anonymized.nii.gz
# 15 	 http://www.nitrc.org/ir/data/experiments/xnat_E00025/scans/anat_mprage_anonymized/resources/11982/files/scan_mprage_anonymized.nii.gz
# 15 	 http://www.nitrc.org/ir/data/experiments/xnat_E00958/scans/anat_mprage_anonymized/resources/14923/files/scan_mprage_anonymized.nii.gz
# 15 	 http://www.nitrc.org/ir/data/experiments/xnat_E00939/scans/anat_mprage_anonymized/resources/14866/files/scan_mprage_anonymized.nii.gz
# 15 	 http://www.nitrc.org/ir/data/experiments/xnat_E00983/scans/anat_mprage_anonymized/resources/7005/files/scan_mprage_anonymized.nii.gz

# %%
#Get Handedness, Gender, Age, and Image URL for subjects scanned in AnnArbor
qres = g.query (
    """select ?site ?subject ?age ?gender ?hand
    where {
        # ?age_type a ncit:Age .
        # ?gender_type a ncit:Gender .
        # ?hand_type a ncit:HandDom .
        # ?entity ?age_type ?age ;
            # ?gender_type ?gender ;
            # ?hand_type ?hand ;
            prov:wasGeneratedBy/prov:wasAssociatedWith ?subject_entity .
        # ?subject_entity ncit:subjectID ?subject .
        # ?activity prov:wasAssociatedWith ?subject_entity ;
            prov:Used ?site_entity .
        # ?site_entity ncit:SiteID ?site .
        filter (?site = 'AnnArbor')
    } """)

print("Site \t\t SubjectID \t\t Age \t Gender \t Hand \n")
for row in qres:
    print ("%s \t %s  \t %s \t %s \t %s" % row)
# Out:
# Site 		 SubjectID 		 Age 	 Gender 	 Hand
#
# AnnArbor 	 AnnArbor_sub49687  	 13 	 M 	 left
# AnnArbor 	 AnnArbor_sub82334  	 14 	 M 	 right
# AnnArbor 	 AnnArbor_sub20317  	 15 	 M 	 right
# AnnArbor 	 AnnArbor_sub38614  	 14 	 M 	 right
# AnnArbor 	 AnnArbor_sub87745  	 14 	 M 	 right
# AnnArbor 	 AnnArbor_sub86367  	 15 	 M 	 right
# AnnArbor 	 AnnArbor_sub96621  	 15 	 M 	 right
# AnnArbor 	 AnnArbor_sub46727  	 13 	 F 	 right
# AnnArbor 	 AnnArbor_sub16960  	 13 	 M 	 right
